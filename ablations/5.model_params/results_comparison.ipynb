# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read in all the validation_results.log files from the different experiments
n_layer_4 = pd.read_csv('./n_layers_4/validation_results.log')
n_layer_6 = pd.read_csv('./n_layers_6/validation_results.log')
n_layer_8= pd.read_csv('./n_layers_8/validation_results.log')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 2
#       1 # Read in all the validation_results.log files from the different experiments
# ----> 2 n_layer_4 = pd.read_csv('./n_layers_4/validation_results.log')
#       3 n_layer_6 = pd.read_csv('./n_layers_6/validation_results.log')
#       4 n_layer_8= pd.read_csv('./n_layers_8/validation_results.log')
#
# ...

# %%
def ema_smooth(x, alpha=0.2):
    smoothed = []
    last = x[0]
    for v in x:
        last = alpha * v + (1 - alpha) * last
        smoothed.append(last)
    return smoothed

# %%
# Plotting all the validation loss curves for comparison
# Use vaLidation step as x-axis and validation loss as y-axis
plt.figure(figsize=(12, 8))

plt.plot(gqa['step'], gqa[' val_loss'], label='GQA', alpha=0.15, color='teal')
plt.plot(gqa['step'], ema_smooth(gqa[' val_loss']), label='GQA (smoothed)', color='teal')

plt.plot(mha['step'], mha[' val_loss'], label='MHA', alpha=0.15, color='orange')
plt.plot(mha['step'], ema_smooth(mha[' val_loss']), label='MHA (smoothed)', color='orange')

plt.plot(mqa['step'], mqa[' val_loss'], label='MQA', alpha=0.15, color='purple')
plt.plot(mqa['step'], ema_smooth(mqa[' val_loss']), label='MQA (smoothed)', color='purple')

plt.xlabel('Validation Step')
plt.ylabel('Validation Loss')
plt.title('Validation Loss Comparison Across Different Attention Mechanism Setups')
plt.legend()
plt.grid()
plt.show()

# %%
# Plotting all the validation accuracy curves for comparison
plt.figure(figsize=(12, 8))
plt.plot(gqa['step'], gqa[' val_acc'], label='GQA', alpha=0.15, color='teal')
plt.plot(gqa['step'], ema_smooth(gqa[' val_acc']), label='GQA (smoothed)', color='teal')

plt.plot(mha['step'], mha[' val_acc'], label='MHA', alpha=0.15, color='orange')
plt.plot(mha['step'], ema_smooth(mha[' val_acc']), label='MHA (smoothed)', color='orange')

plt.plot(mqa['step'], mqa[' val_acc'], label='MQA', alpha=0.15, color='purple')
plt.plot(mqa['step'], ema_smooth(mqa[' val_acc']), label='MQA (smoothed)', color='purple')

plt.xlabel('Validation Step')
plt.ylabel('Validation Accuracy')
plt.title('Validation Accuracy Comparison Across Different Attention Mechanisms')
plt.legend()
plt.grid()
plt.show()

# %%
# Plotting all the validation accuracy at the last character curves for comparison
plt.figure(figsize=(12, 8))
plt.plot(gqa['step'], gqa[' last_char_val_acc'], label='GQA', alpha=0.15, color='teal')
plt.plot(gqa['step'], ema_smooth(gqa[' last_char_val_acc']), label='GQA (smoothed)', color='teal')

plt.plot(mha['step'], mha[' last_char_val_acc'], label='MHA', alpha=0.15, color='orange')
plt.plot(mha['step'], ema_smooth(mha[' last_char_val_acc']), label='MHA (smoothed)', color='orange')

plt.plot(mqa['step'], mqa[' last_char_val_acc'], label='MQA', alpha=0.15, color='purple')
plt.plot(mqa['step'], ema_smooth(mqa[' last_char_val_acc']), label='MQA (smoothed)', color='purple')

plt.xlabel('Validation Step')
plt.ylabel('Validation Accuracy at Last Character')
plt.title('Validation Accuracy at Last Character Comparison Across Different Attention Mechanism Setups')
plt.legend()
plt.grid()
plt.show()
