# %% [markdown]
# # Ablations Experiment for Mixed Precision study
#
# In this notebook, we created and trained a transformer model based on our ablation experiment setup, specifically to observe the effects of changes in whether mixed precision is used. The architecture is defined as per the 'experiment_model.py' file, and we utilise functions created in the 'experiment_utils.py' file to facilitate the training process.
#
# The flow of this notebook is similar to that of the baseline model, but with modifications to accommodate the ablation study requirements. The loss values are recorded for upcoming analysis, visualization and cross comparison.

# %%
import matplotlib.pyplot as plt
import optax
import sys
import jax
import time
import os
import numpy as np
from pathlib import Path

cwd = Path.cwd()

# Project root for local setup
project_root = cwd.parents[0]

from ablations.experiment_setup import experiment_utils as fn
# Out:
# /usr/local/lib/python3.12/dist-packages/jax/_src/cloud_tpu_init.py:86: UserWarning: Transparent hugepages are not enabled. TPU runtime startup and shutdown time should be significantly improved on TPU v5e and newer. If not already set, you may need to enable transparent hugepages in your VM image (sudo sh -c "echo always > /sys/kernel/mm/transparent_hugepage/enabled")
#   warnings.warn(

# %% [markdown]
# # Load the Experiment Setup

# %% [markdown]
# ## Set the relevant directory paths & update.log file
#
# Here, we set the necessary directories and output paths for saving model checkpoints and training logs.

# %%
# Data directory paths
local_dir = project_root / "data" / "text8_train.txt"
online_dir = project_root / "text8_train.txt"

if local_dir.exists():
    data_dir = str(local_dir) # This is for local runs or if repository is cloned directly
else:
    data_dir = "." + str(online_dir) # This is for online GPU platforms

config_path = cwd / "config.json"
training_log_file = cwd / "training_results.log"
validation_log_file = cwd / "validation_results.log"
checkpoint_file = cwd / "checkpoint.pkl"

# %%
if not os.path.exists(training_log_file):
    fn.initialize_training_log(training_log_file)

if not os.path.exists(validation_log_file):
    fn.initialize_validation_log(validation_log_file)
# Out:
# [initialize_training_log] Initialized training log file at /content/training_results.log
# [initialize_validation_log] Initialized validation log file at /content/validation_results.log

# %% [markdown]
# ## Load the experiment configurations
#
# Prior to running this notebook, the experiment configurations will be set in a 'config.json' file, which will be loaded to set the model hyperparameters and training settings.

# %%
config = fn.load_config("./config.json")

print(f"We will be conducting {config['description']}.")
# Out:
# [load_config] Loaded configuration from ./config.json
# We will be conducting Ablation test for mixed precision set to false..

# %%
# Load the seed
seed = config['seed']

# Model parameters
vocab_size = config['model']['vocab_size']
d_model = config['model']['d_model']
n_heads = config['model']['n_heads']
n_layers = config['model']['n_layers']
mlp_ratio = config['model']['mlp_ratio']
seq_len = config['model']['seq_len']

# Training parameters
loss_type = config['model']['loss_type']
dropout_rate = config['model']['dropout']
weight_decay = config['model']['weight_decay']
label_smoothing = config['model']['label_smoothing']

# Mixed precision and other model settings
use_mixed_precision = config['model']['mixed_precision']
pos_encoding = config['model']['pos_encoding']
attention_type = config['model']['attention_type']

# Auxiliary loss settings
use_auxiliary_loss = config['model']['use_auxiliary_loss']
aux_heads = config['model']['aux_heads']
aux_weight = config['model']['aux_weight']

# %%
# Throughput test parameters
max_test_iters = config['throughput']['max_test_iters']
max_test_time_in_seconds = config['throughput']['max_test_time_in_seconds']
compute_budget_hours = config['throughput']['compute_budget_hours']

# Training settings
val_fraction = config['training']['val_fraction']
batch_size = config['training']['batch_size']
learning_rate = config['training']['learning_rate']
lr_schedule = config['training']['lr_schedule']
optimizer_type = config['training']['optimizer']

# %% [markdown]
# # Loading the Data
#
# The same text8 dataset is used, which has 100M characters of text data from Wikipedia articles. It contains only lowercase letters and spaces, and is already pre-split into 90M characters for training and 10M characters for testing.

# %%
# Read in training text file
with open(data_dir, 'r', encoding='utf-8') as f:
    train_text = f.read()
print(f"Training text loaded. Length: {len(train_text) :,} characters.")

# Inspect first 500 characters of training text
print("First 500 characters of training text:")
print(train_text[:500])
# Out:
# Training text loaded. Length: 90,000,000 characters.
# First 500 characters of training text:
#  anarchism originated as a term of abuse first used against early working class radicals including the diggers of the english revolution and the sans culottes of the french revolution whilst the term is still used in a pejorative way to describe any act that used violent means to destroy the organization of society it has also been taken up as a positive label by self defined anarchists the word anarchism is derived from the greek without archons ruler chief king anarchism as a political philoso

# %%
chars = sorted(set(train_text)) # unique characters in training text
chars_to_int = {ch: i for i, ch in enumerate(chars)} # char to int mapping
int_to_chars = {i: ch for i, ch in enumerate(chars)} # int to char mapping

print(f"Unique characters in training text: {len(chars)}") # should be 27, including space (sanity check)
# Out:
# Unique characters in training text: 27

# %% [markdown]
# We further split the training data into a training set and a validation set to monitor the model's performance during training, in accordance to the validation fraction specified in our configuration file (10%)

# %%
train_text, val_text = fn.split_train_val(train_text, val_fraction=val_fraction)

print(f"Training text length: {len(train_text) :,} characters.")
print(f"Validation text length: {len(val_text) :,} characters.")
# Out:
# Training text length: 89,099,996 characters.
# Validation text length: 900,004 characters.

# %% [markdown]
# # Model Initialisation

# %% [markdown]
# ## Model Setup
#
# We intialise our model with the following parameters in accordance to our configuration file.
# Based on these parameters, our model has approximately ~4.7M parameters.

# %%
# Define the model params
rng = jax.random.PRNGKey(seed)

model_obj, params, constants = fn.create_train_state(
        rng,
        vocab_size = vocab_size,
        d_model = d_model,
        n_heads = n_heads,
        n_layers = n_layers,
        mlp_ratio = mlp_ratio,
        seq_len = seq_len,
        dropout = dropout_rate,
        aux_loss = use_auxiliary_loss,
        num_aux_heads = aux_heads,
        mixed_precision = use_mixed_precision,
        attention_type = attention_type,
        pos_encoding = pos_encoding
)

# %%
total_params = fn.count_parameters(params)

print(f"Total number of parameters in the model: {total_params :,}")
# Out:
# Total number of parameters in the model: 4,752,896

# %% [markdown]
# We perform a sanity check by running a single forward pass with random input data to ensure the model is functioning as expected.

# %%
# SANITY CHECK: Test the model forward pass
B, T = 2, 8  # Batch size and sequence length
batch = jax.random.randint(key = rng, shape = (B, T), minval = 0, maxval = vocab_size)

variables = {"params": params, "constants": constants}
output = model_obj.apply(variables, batch, deterministic=False)
print("Logits shape:", output["logits"].shape)  # Expected: (B, T, vocab_size)
# Out:
# Logits shape: (2, 8, 27)

# %% [markdown]
# ## Initialise the optimizer
#
# In this section, we set up the optimizer for training our model in accordance to our configuration file.

# %%
# Define the learning rate
learning_rate = learning_rate

# Create the Optimizer and initialize it
if optimizer_type == "adam":
    optimizer = optax.adam(learning_rate)
elif optimizer_type == "sgd":
    optimizer = optax.sgd(learning_rate)
elif optimizer_type == "adamw":
    optimizer = optax.adamw(
        learning_rate = learning_rate,
        weight_decay = weight_decay
    )

opt_state = optimizer.init(params)

print("Optimizer initialized:", optimizer_type, "with Learning Rate =", learning_rate)
# Out:
# Optimizer initialized: adam with Learning Rate = 0.001

# %% [markdown]
# ## Text encoding
#
# We then encode the text data into integer format for model training. Each unique character is mapped to a unique integer index.

# %%
# Encode the train, val, test texts
train_data = fn.encode(train_text, chars_to_int)
val_data = fn.encode(val_text, chars_to_int)

# %% [markdown]
# ## Determine maximum permissible training steps
#
# Taking into account possible compute limitations, we perform a preliminary calculation to determine the maximum number of training steps we can perform based on the throughput of our model and the total training time available. For this preliminary test, the default maximum training time is 60 seconds, and commpute budget hours is 2 hours.
#
# Based on the throughput calculated from the preliminary test, the estimated maximum no. of training steps we can perform within this compute budget is ~360,000. To ensure we keep within the budget, we set the maximum training steps to be 150,000.

# %%
# Determining how many steps we can run in a reasonable time
max_iters = max_test_iters
max_time = max_test_time_in_seconds # in seconds
max_compute_time = compute_budget_hours # in hours

_ , max_steps = fn.calculate_throughput(
    max_test_iters = max_iters,
    max_test_time = max_time,
    model = model_obj,
    params = params,
    opt_state = opt_state,
    optimizer = optimizer,
    rng = rng,
    batch_size = batch_size,
    seq_len = seq_len,
    compute_budget = max_compute_time,
    train_data = train_data,
    loss_type = loss_type,
    aux_loss = use_auxiliary_loss,
    aux_weight = aux_weight,
    constants = constants
)
# Out:
# Benchmark completed in 20.14 seconds.
# Total tokens processed: 8192000
# Throughput: 406659.51 tokens/second
# Estimated max steps within compute budget: 357415.0

# %% [markdown]
# # Model Training & Evaluation

# %% [markdown]
# ## Training the model
#
# Now, we proceed to train the model over the determined number of training iterations. During training, we monitor the training loss and periodically evaluate the model on the validation set to track its performance. We also make sure to record the time taken for training to ensure it stays within our compute budget.

# %%
iter_max = 150000

# To track training and validation loss, as well as time taken
train_loss_history = []
val_loss_history = []
train_step_history = list(range(iter_max))
val_step_history = []

# Load checkpoint if it exists
params, opt_state, constants, start_iter = fn.load_checkpoint(
    checkpoint_file,
    params,
    constants,
    opt_state
)
# Out:
# [load_checkpoint] No checkpoint found at /content/checkpoint.pkl
# [load_checkpoint] Starting training as per usual.

# %% [markdown]
# We then train the model and log the training and validation losses for analysis.

# %%
if start_iter > 0:
        print(f"Resuming training from iteration = {start_iter}.")
else:
        print("Starting training from iteration = 0.")

time_start = time.time()

for it in range(start_iter, iter_max):

    # get a batch of data
    inputs, targets = fn.get_batch(train_data, batch_size, seq_len)

    # Perform a training step
    rng, sub = jax.random.split(rng)
    new_params, new_opt_state, metrics = fn.train_step(
            model = model_obj,
            params = params,
            constants=constants,
            opt_state = opt_state,
            x = inputs,
            y = targets,
            tx = optimizer,
            rng = sub,
            loss_type = loss_type,
            aux_loss = use_auxiliary_loss,
            aux_weight = aux_weight
    )

    # Update parameters and optimizer state
    params = new_params
    opt_state = new_opt_state

    # Record training metrics
    acc = metrics['acc']
    loss = metrics['loss']
    last_char_acc = metrics['acc_last']
    train_time = time.time() - time_start

    train_loss_history.append(loss)

    fn.update_training_log(
        log_path = "training_results.log",
        step = it,
        train_loss = loss,
        train_time = train_time,
        train_acc = acc,
        last_char_acc = last_char_acc
        )

    log_every = max(1, iter_max // 100)

    if (it % log_every) == 0 or (it == iter_max - 1): # Print every 1% of iterations

        # Compute the loss on validation set
        batch_size_val = batch_size
        seq_len_val = seq_len
        val_inputs, val_targets = fn.get_batch(val_data, batch_size_val, seq_len_val)

        val_out = model_obj.apply({"params": params, "constants": constants}, val_inputs, deterministic=True)
        val_logits = val_out["logits"]
        val_aux_logits = val_out.get('aux_logits', None)

        val_loss, val_metrics = fn.loss_and_metrics(
              logits = val_logits,
              targets = val_targets,
              loss_type = loss_type,
              aux_loss = use_auxiliary_loss,
              aux_logits = val_aux_logits,
              aux_weight = aux_weight
        )

        # Record validation loss and time
        val_acc = val_metrics['acc']
        last_char_acc_val = val_metrics['acc_last']
        val_loss_history.append(val_loss)
        time_elapsed = time.time() - time_start
        val_step_history.append(it)

        fn.update_validation_log(
            log_path = "validation_results.log",
            step = it,
            val_loss = val_loss,
            val_time = time_elapsed,
            val_acc = val_acc,
            last_char_val_acc = last_char_acc_val
        )

        fn.save_checkpoint(
            checkpoint_path = checkpoint_file,
            params = params,
            constants = constants,
            opt_state = opt_state,
            step = it,
            time_elapsed = time_elapsed
        )

        # Print training and validation metrics
        print(f"Iteration {it}, time elapsed: {time_elapsed:.2f} seconds")
        print(f"\t \t Training Loss: {loss:.4f}, Validation Loss: {val_loss:.4f}")
        print(f"\t \t Training Acc: {acc:.4f}, Validation Acc: {val_acc:.4f}")
        print(f"\t \t Last Char Training Acc: {last_char_acc:.4f}, Last Char Validation Acc: {last_char_acc_val:.4f}")
        print("-" * 50)

print(f"Training completed in {time.time() - time_start:.2f} seconds.")
# Out:
# Starting training from iteration = 0.
# [save_checkpoint] Saved checkpoint at step 0 to /content/checkpoint.pkl
# Iteration 0, time elapsed: 6.13 seconds
# 	 	 Training Loss: 3.6693, Validation Loss: 4.6150
# 	 	 Training Acc: 0.0649, Validation Acc: 0.1669
# 	 	 Last Char Training Acc: 0.0938, Last Char Validation Acc: 0.1250
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 1500 to /content/checkpoint.pkl
# Iteration 1500, time elapsed: 17.05 seconds
# 	 	 Training Loss: 1.3628, Validation Loss: 1.3863
# 	 	 Training Acc: 0.5724, Validation Acc: 0.5597
# 	 	 Last Char Training Acc: 0.5625, Last Char Validation Acc: 0.4375
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 3000 to /content/checkpoint.pkl
# Iteration 3000, time elapsed: 27.59 seconds
# 	 	 Training Loss: 1.3751, Validation Loss: 1.2450
# 	 	 Training Acc: 0.5719, Validation Acc: 0.6045
# 	 	 Last Char Training Acc: 0.5312, Last Char Validation Acc: 0.5938
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 4500 to /content/checkpoint.pkl
# Iteration 4500, time elapsed: 38.45 seconds
# 	 	 Training Loss: 1.2390, Validation Loss: 1.2405
# 	 	 Training Acc: 0.6071, Validation Acc: 0.6091
# 	 	 Last Char Training Acc: 0.6250, Last Char Validation Acc: 0.5000
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 6000 to /content/checkpoint.pkl
# Iteration 6000, time elapsed: 49.32 seconds
# 	 	 Training Loss: 1.2365, Validation Loss: 1.2586
# 	 	 Training Acc: 0.6140, Validation Acc: 0.6053
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.6250
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 7500 to /content/checkpoint.pkl
# Iteration 7500, time elapsed: 60.43 seconds
# 	 	 Training Loss: 1.2272, Validation Loss: 1.1953
# 	 	 Training Acc: 0.6110, Validation Acc: 0.6163
# 	 	 Last Char Training Acc: 0.7188, Last Char Validation Acc: 0.5938
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 9000 to /content/checkpoint.pkl
# Iteration 9000, time elapsed: 71.38 seconds
# 	 	 Training Loss: 1.1748, Validation Loss: 1.3043
# 	 	 Training Acc: 0.6263, Validation Acc: 0.5946
# 	 	 Last Char Training Acc: 0.5625, Last Char Validation Acc: 0.5312
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 10500 to /content/checkpoint.pkl
# Iteration 10500, time elapsed: 82.30 seconds
# 	 	 Training Loss: 1.1745, Validation Loss: 1.2812
# 	 	 Training Acc: 0.6340, Validation Acc: 0.5975
# 	 	 Last Char Training Acc: 0.6250, Last Char Validation Acc: 0.5938
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 12000 to /content/checkpoint.pkl
# Iteration 12000, time elapsed: 93.26 seconds
# 	 	 Training Loss: 1.1946, Validation Loss: 1.2337
# 	 	 Training Acc: 0.6254, Validation Acc: 0.6150
# 	 	 Last Char Training Acc: 0.6875, Last Char Validation Acc: 0.5312
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 13500 to /content/checkpoint.pkl
# Iteration 13500, time elapsed: 104.17 seconds
# 	 	 Training Loss: 1.1659, Validation Loss: 1.1567
# 	 	 Training Acc: 0.6343, Validation Acc: 0.6309
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.7500
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 15000 to /content/checkpoint.pkl
# Iteration 15000, time elapsed: 115.11 seconds
# 	 	 Training Loss: 1.1879, Validation Loss: 1.1858
# 	 	 Training Acc: 0.6321, Validation Acc: 0.6257
# 	 	 Last Char Training Acc: 0.4062, Last Char Validation Acc: 0.4688
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 16500 to /content/checkpoint.pkl
# Iteration 16500, time elapsed: 125.99 seconds
# 	 	 Training Loss: 1.1397, Validation Loss: 1.1549
# 	 	 Training Acc: 0.6417, Validation Acc: 0.6346
# 	 	 Last Char Training Acc: 0.6875, Last Char Validation Acc: 0.5000
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 18000 to /content/checkpoint.pkl
# Iteration 18000, time elapsed: 137.09 seconds
# 	 	 Training Loss: 1.1620, Validation Loss: 1.2207
# 	 	 Training Acc: 0.6364, Validation Acc: 0.6230
# 	 	 Last Char Training Acc: 0.6875, Last Char Validation Acc: 0.5312
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 19500 to /content/checkpoint.pkl
# Iteration 19500, time elapsed: 148.33 seconds
# 	 	 Training Loss: 1.1938, Validation Loss: 1.2475
# 	 	 Training Acc: 0.6246, Validation Acc: 0.6125
# 	 	 Last Char Training Acc: 0.6250, Last Char Validation Acc: 0.5312
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 21000 to /content/checkpoint.pkl
# Iteration 21000, time elapsed: 159.48 seconds
# 	 	 Training Loss: 1.0817, Validation Loss: 1.2155
# 	 	 Training Acc: 0.6545, Validation Acc: 0.6201
# 	 	 Last Char Training Acc: 0.6875, Last Char Validation Acc: 0.6562
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 22500 to /content/checkpoint.pkl
# Iteration 22500, time elapsed: 170.32 seconds
# 	 	 Training Loss: 1.1883, Validation Loss: 1.1084
# 	 	 Training Acc: 0.6274, Validation Acc: 0.6489
# 	 	 Last Char Training Acc: 0.6562, Last Char Validation Acc: 0.6250
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 24000 to /content/checkpoint.pkl
# Iteration 24000, time elapsed: 181.31 seconds
# 	 	 Training Loss: 1.1535, Validation Loss: 1.1608
# 	 	 Training Acc: 0.6416, Validation Acc: 0.6350
# 	 	 Last Char Training Acc: 0.4688, Last Char Validation Acc: 0.5625
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 25500 to /content/checkpoint.pkl
# Iteration 25500, time elapsed: 192.37 seconds
# 	 	 Training Loss: 1.1270, Validation Loss: 1.1570
# 	 	 Training Acc: 0.6425, Validation Acc: 0.6311
# 	 	 Last Char Training Acc: 0.5938, Last Char Validation Acc: 0.5312
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 27000 to /content/checkpoint.pkl
# Iteration 27000, time elapsed: 203.51 seconds
# 	 	 Training Loss: 1.1625, Validation Loss: 1.1189
# 	 	 Training Acc: 0.6379, Validation Acc: 0.6517
# 	 	 Last Char Training Acc: 0.6250, Last Char Validation Acc: 0.6562
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 28500 to /content/checkpoint.pkl
# Iteration 28500, time elapsed: 214.37 seconds
# 	 	 Training Loss: 1.1192, Validation Loss: 1.1344
# 	 	 Training Acc: 0.6458, Validation Acc: 0.6482
# 	 	 Last Char Training Acc: 0.5938, Last Char Validation Acc: 0.6250
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 30000 to /content/checkpoint.pkl
# Iteration 30000, time elapsed: 225.56 seconds
# 	 	 Training Loss: 1.0378, Validation Loss: 1.1110
# 	 	 Training Acc: 0.6689, Validation Acc: 0.6495
# 	 	 Last Char Training Acc: 0.7812, Last Char Validation Acc: 0.6562
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 31500 to /content/checkpoint.pkl
# Iteration 31500, time elapsed: 235.93 seconds
# 	 	 Training Loss: 1.1161, Validation Loss: 1.1299
# 	 	 Training Acc: 0.6523, Validation Acc: 0.6486
# 	 	 Last Char Training Acc: 0.5625, Last Char Validation Acc: 0.5312
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 33000 to /content/checkpoint.pkl
# Iteration 33000, time elapsed: 246.73 seconds
# 	 	 Training Loss: 1.0795, Validation Loss: 1.1115
# 	 	 Training Acc: 0.6649, Validation Acc: 0.6532
# 	 	 Last Char Training Acc: 0.7188, Last Char Validation Acc: 0.7812
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 34500 to /content/checkpoint.pkl
# Iteration 34500, time elapsed: 257.82 seconds
# 	 	 Training Loss: 1.0745, Validation Loss: 1.0936
# 	 	 Training Acc: 0.6616, Validation Acc: 0.6552
# 	 	 Last Char Training Acc: 0.6250, Last Char Validation Acc: 0.6562
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 36000 to /content/checkpoint.pkl
# Iteration 36000, time elapsed: 268.79 seconds
# 	 	 Training Loss: 1.1156, Validation Loss: 1.0875
# 	 	 Training Acc: 0.6492, Validation Acc: 0.6555
# 	 	 Last Char Training Acc: 0.5625, Last Char Validation Acc: 0.6875
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 37500 to /content/checkpoint.pkl
# Iteration 37500, time elapsed: 279.96 seconds
# 	 	 Training Loss: 1.0619, Validation Loss: 1.0823
# 	 	 Training Acc: 0.6700, Validation Acc: 0.6625
# 	 	 Last Char Training Acc: 0.6250, Last Char Validation Acc: 0.8125
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 39000 to /content/checkpoint.pkl
# Iteration 39000, time elapsed: 290.82 seconds
# 	 	 Training Loss: 1.1573, Validation Loss: 1.1370
# 	 	 Training Acc: 0.6395, Validation Acc: 0.6421
# 	 	 Last Char Training Acc: 0.5625, Last Char Validation Acc: 0.7188
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 40500 to /content/checkpoint.pkl
# Iteration 40500, time elapsed: 301.62 seconds
# 	 	 Training Loss: 1.0161, Validation Loss: 1.1021
# 	 	 Training Acc: 0.6810, Validation Acc: 0.6554
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.6250
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 42000 to /content/checkpoint.pkl
# Iteration 42000, time elapsed: 312.64 seconds
# 	 	 Training Loss: 1.0346, Validation Loss: 1.1301
# 	 	 Training Acc: 0.6729, Validation Acc: 0.6344
# 	 	 Last Char Training Acc: 0.6875, Last Char Validation Acc: 0.7812
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 43500 to /content/checkpoint.pkl
# Iteration 43500, time elapsed: 323.34 seconds
# 	 	 Training Loss: 1.0716, Validation Loss: 1.0787
# 	 	 Training Acc: 0.6571, Validation Acc: 0.6582
# 	 	 Last Char Training Acc: 0.5938, Last Char Validation Acc: 0.6875
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 45000 to /content/checkpoint.pkl
# Iteration 45000, time elapsed: 334.31 seconds
# 	 	 Training Loss: 1.0747, Validation Loss: 1.1284
# 	 	 Training Acc: 0.6624, Validation Acc: 0.6499
# 	 	 Last Char Training Acc: 0.6250, Last Char Validation Acc: 0.6562
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 46500 to /content/checkpoint.pkl
# Iteration 46500, time elapsed: 345.14 seconds
# 	 	 Training Loss: 1.0523, Validation Loss: 1.0560
# 	 	 Training Acc: 0.6692, Validation Acc: 0.6678
# 	 	 Last Char Training Acc: 0.7812, Last Char Validation Acc: 0.7812
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 48000 to /content/checkpoint.pkl
# Iteration 48000, time elapsed: 356.17 seconds
# 	 	 Training Loss: 1.0931, Validation Loss: 1.0762
# 	 	 Training Acc: 0.6600, Validation Acc: 0.6589
# 	 	 Last Char Training Acc: 0.6875, Last Char Validation Acc: 0.5312
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 49500 to /content/checkpoint.pkl
# Iteration 49500, time elapsed: 367.51 seconds
# 	 	 Training Loss: 1.0871, Validation Loss: 1.1265
# 	 	 Training Acc: 0.6522, Validation Acc: 0.6487
# 	 	 Last Char Training Acc: 0.6875, Last Char Validation Acc: 0.6562
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 51000 to /content/checkpoint.pkl
# Iteration 51000, time elapsed: 378.66 seconds
# 	 	 Training Loss: 1.1154, Validation Loss: 1.0480
# 	 	 Training Acc: 0.6519, Validation Acc: 0.6720
# 	 	 Last Char Training Acc: 0.7812, Last Char Validation Acc: 0.9062
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 52500 to /content/checkpoint.pkl
# Iteration 52500, time elapsed: 389.37 seconds
# 	 	 Training Loss: 1.0497, Validation Loss: 1.0506
# 	 	 Training Acc: 0.6694, Validation Acc: 0.6652
# 	 	 Last Char Training Acc: 0.5938, Last Char Validation Acc: 0.7188
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 54000 to /content/checkpoint.pkl
# Iteration 54000, time elapsed: 400.12 seconds
# 	 	 Training Loss: 1.0584, Validation Loss: 1.0507
# 	 	 Training Acc: 0.6683, Validation Acc: 0.6700
# 	 	 Last Char Training Acc: 0.6875, Last Char Validation Acc: 0.7500
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 55500 to /content/checkpoint.pkl
# Iteration 55500, time elapsed: 410.54 seconds
# 	 	 Training Loss: 1.0502, Validation Loss: 1.0832
# 	 	 Training Acc: 0.6680, Validation Acc: 0.6572
# 	 	 Last Char Training Acc: 0.7188, Last Char Validation Acc: 0.7500
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 57000 to /content/checkpoint.pkl
# Iteration 57000, time elapsed: 421.51 seconds
# 	 	 Training Loss: 1.0535, Validation Loss: 1.0842
# 	 	 Training Acc: 0.6733, Validation Acc: 0.6566
# 	 	 Last Char Training Acc: 0.6562, Last Char Validation Acc: 0.7500
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 58500 to /content/checkpoint.pkl
# Iteration 58500, time elapsed: 432.75 seconds
# 	 	 Training Loss: 1.0656, Validation Loss: 1.1002
# 	 	 Training Acc: 0.6658, Validation Acc: 0.6549
# 	 	 Last Char Training Acc: 0.7188, Last Char Validation Acc: 0.4062
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 60000 to /content/checkpoint.pkl
# Iteration 60000, time elapsed: 443.76 seconds
# 	 	 Training Loss: 1.1030, Validation Loss: 1.0608
# 	 	 Training Acc: 0.6542, Validation Acc: 0.6682
# 	 	 Last Char Training Acc: 0.6562, Last Char Validation Acc: 0.7812
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 61500 to /content/checkpoint.pkl
# Iteration 61500, time elapsed: 454.78 seconds
# 	 	 Training Loss: 1.0591, Validation Loss: 1.0898
# 	 	 Training Acc: 0.6655, Validation Acc: 0.6594
# 	 	 Last Char Training Acc: 0.6250, Last Char Validation Acc: 0.6562
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 63000 to /content/checkpoint.pkl
# Iteration 63000, time elapsed: 465.85 seconds
# 	 	 Training Loss: 1.0361, Validation Loss: 1.0648
# 	 	 Training Acc: 0.6797, Validation Acc: 0.6604
# 	 	 Last Char Training Acc: 0.7188, Last Char Validation Acc: 0.5938
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 64500 to /content/checkpoint.pkl
# Iteration 64500, time elapsed: 476.90 seconds
# 	 	 Training Loss: 1.0195, Validation Loss: 1.0213
# 	 	 Training Acc: 0.6761, Validation Acc: 0.6802
# 	 	 Last Char Training Acc: 0.8750, Last Char Validation Acc: 0.7188
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 66000 to /content/checkpoint.pkl
# Iteration 66000, time elapsed: 487.64 seconds
# 	 	 Training Loss: 1.0388, Validation Loss: 1.0817
# 	 	 Training Acc: 0.6724, Validation Acc: 0.6549
# 	 	 Last Char Training Acc: 0.6875, Last Char Validation Acc: 0.6250
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 67500 to /content/checkpoint.pkl
# Iteration 67500, time elapsed: 498.44 seconds
# 	 	 Training Loss: 0.9958, Validation Loss: 1.0693
# 	 	 Training Acc: 0.6831, Validation Acc: 0.6661
# 	 	 Last Char Training Acc: 0.6562, Last Char Validation Acc: 0.6875
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 69000 to /content/checkpoint.pkl
# Iteration 69000, time elapsed: 509.11 seconds
# 	 	 Training Loss: 1.0901, Validation Loss: 1.0225
# 	 	 Training Acc: 0.6582, Validation Acc: 0.6801
# 	 	 Last Char Training Acc: 0.5625, Last Char Validation Acc: 0.6562
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 70500 to /content/checkpoint.pkl
# Iteration 70500, time elapsed: 520.34 seconds
# 	 	 Training Loss: 1.0324, Validation Loss: 0.9807
# 	 	 Training Acc: 0.6759, Validation Acc: 0.6880
# 	 	 Last Char Training Acc: 0.6875, Last Char Validation Acc: 0.6562
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 72000 to /content/checkpoint.pkl
# Iteration 72000, time elapsed: 531.30 seconds
# 	 	 Training Loss: 1.0377, Validation Loss: 1.0293
# 	 	 Training Acc: 0.6744, Validation Acc: 0.6748
# 	 	 Last Char Training Acc: 0.7812, Last Char Validation Acc: 0.8438
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 73500 to /content/checkpoint.pkl
# Iteration 73500, time elapsed: 542.24 seconds
# 	 	 Training Loss: 1.0070, Validation Loss: 1.0714
# 	 	 Training Acc: 0.6826, Validation Acc: 0.6676
# 	 	 Last Char Training Acc: 0.6875, Last Char Validation Acc: 0.7188
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 75000 to /content/checkpoint.pkl
# Iteration 75000, time elapsed: 553.16 seconds
# 	 	 Training Loss: 0.9970, Validation Loss: 1.0485
# 	 	 Training Acc: 0.6860, Validation Acc: 0.6683
# 	 	 Last Char Training Acc: 0.7812, Last Char Validation Acc: 0.6875
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 76500 to /content/checkpoint.pkl
# Iteration 76500, time elapsed: 564.15 seconds
# 	 	 Training Loss: 1.0218, Validation Loss: 1.0755
# 	 	 Training Acc: 0.6764, Validation Acc: 0.6595
# 	 	 Last Char Training Acc: 0.7188, Last Char Validation Acc: 0.7812
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 78000 to /content/checkpoint.pkl
# Iteration 78000, time elapsed: 575.09 seconds
# 	 	 Training Loss: 0.9824, Validation Loss: 1.0935
# 	 	 Training Acc: 0.6855, Validation Acc: 0.6571
# 	 	 Last Char Training Acc: 0.8438, Last Char Validation Acc: 0.6875
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 79500 to /content/checkpoint.pkl
# Iteration 79500, time elapsed: 586.02 seconds
# 	 	 Training Loss: 0.9964, Validation Loss: 1.0342
# 	 	 Training Acc: 0.6886, Validation Acc: 0.6675
# 	 	 Last Char Training Acc: 0.6562, Last Char Validation Acc: 0.6875
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 81000 to /content/checkpoint.pkl
# Iteration 81000, time elapsed: 597.01 seconds
# 	 	 Training Loss: 1.0110, Validation Loss: 1.0856
# 	 	 Training Acc: 0.6816, Validation Acc: 0.6586
# 	 	 Last Char Training Acc: 0.6562, Last Char Validation Acc: 0.7812
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 82500 to /content/checkpoint.pkl
# Iteration 82500, time elapsed: 607.29 seconds
# 	 	 Training Loss: 0.9744, Validation Loss: 1.0675
# 	 	 Training Acc: 0.6993, Validation Acc: 0.6654
# 	 	 Last Char Training Acc: 0.7188, Last Char Validation Acc: 0.8438
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 84000 to /content/checkpoint.pkl
# Iteration 84000, time elapsed: 618.49 seconds
# 	 	 Training Loss: 1.0483, Validation Loss: 1.0734
# 	 	 Training Acc: 0.6718, Validation Acc: 0.6658
# 	 	 Last Char Training Acc: 0.7812, Last Char Validation Acc: 0.6562
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 85500 to /content/checkpoint.pkl
# Iteration 85500, time elapsed: 629.15 seconds
# 	 	 Training Loss: 1.0454, Validation Loss: 1.0996
# 	 	 Training Acc: 0.6714, Validation Acc: 0.6533
# 	 	 Last Char Training Acc: 0.6562, Last Char Validation Acc: 0.7500
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 87000 to /content/checkpoint.pkl
# Iteration 87000, time elapsed: 640.23 seconds
# 	 	 Training Loss: 1.0618, Validation Loss: 1.1033
# 	 	 Training Acc: 0.6675, Validation Acc: 0.6589
# 	 	 Last Char Training Acc: 0.6875, Last Char Validation Acc: 0.6875
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 88500 to /content/checkpoint.pkl
# Iteration 88500, time elapsed: 651.32 seconds
# 	 	 Training Loss: 1.0283, Validation Loss: 1.0779
# 	 	 Training Acc: 0.6768, Validation Acc: 0.6638
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.6562
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 90000 to /content/checkpoint.pkl
# Iteration 90000, time elapsed: 662.41 seconds
# 	 	 Training Loss: 1.0407, Validation Loss: 1.0772
# 	 	 Training Acc: 0.6782, Validation Acc: 0.6531
# 	 	 Last Char Training Acc: 0.5938, Last Char Validation Acc: 0.5938
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 91500 to /content/checkpoint.pkl
# Iteration 91500, time elapsed: 673.48 seconds
# 	 	 Training Loss: 1.0284, Validation Loss: 1.1028
# 	 	 Training Acc: 0.6783, Validation Acc: 0.6584
# 	 	 Last Char Training Acc: 0.7188, Last Char Validation Acc: 0.7500
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 93000 to /content/checkpoint.pkl
# Iteration 93000, time elapsed: 684.41 seconds
# 	 	 Training Loss: 0.9848, Validation Loss: 0.9971
# 	 	 Training Acc: 0.6918, Validation Acc: 0.6841
# 	 	 Last Char Training Acc: 0.7188, Last Char Validation Acc: 0.7500
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 94500 to /content/checkpoint.pkl
# Iteration 94500, time elapsed: 695.29 seconds
# 	 	 Training Loss: 1.0432, Validation Loss: 1.1143
# 	 	 Training Acc: 0.6748, Validation Acc: 0.6497
# 	 	 Last Char Training Acc: 0.7188, Last Char Validation Acc: 0.6875
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 96000 to /content/checkpoint.pkl
# Iteration 96000, time elapsed: 706.35 seconds
# 	 	 Training Loss: 1.0535, Validation Loss: 1.0549
# 	 	 Training Acc: 0.6686, Validation Acc: 0.6718
# 	 	 Last Char Training Acc: 0.6875, Last Char Validation Acc: 0.8125
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 97500 to /content/checkpoint.pkl
# Iteration 97500, time elapsed: 717.49 seconds
# 	 	 Training Loss: 1.0470, Validation Loss: 1.0031
# 	 	 Training Acc: 0.6722, Validation Acc: 0.6846
# 	 	 Last Char Training Acc: 0.6562, Last Char Validation Acc: 0.7188
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 99000 to /content/checkpoint.pkl
# Iteration 99000, time elapsed: 728.84 seconds
# 	 	 Training Loss: 1.0334, Validation Loss: 1.0651
# 	 	 Training Acc: 0.6732, Validation Acc: 0.6655
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.8125
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 100500 to /content/checkpoint.pkl
# Iteration 100500, time elapsed: 739.97 seconds
# 	 	 Training Loss: 0.9845, Validation Loss: 1.0546
# 	 	 Training Acc: 0.6859, Validation Acc: 0.6660
# 	 	 Last Char Training Acc: 0.5625, Last Char Validation Acc: 0.6250
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 102000 to /content/checkpoint.pkl
# Iteration 102000, time elapsed: 750.99 seconds
# 	 	 Training Loss: 0.9932, Validation Loss: 1.0703
# 	 	 Training Acc: 0.6910, Validation Acc: 0.6637
# 	 	 Last Char Training Acc: 0.7188, Last Char Validation Acc: 0.7500
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 103500 to /content/checkpoint.pkl
# Iteration 103500, time elapsed: 761.81 seconds
# 	 	 Training Loss: 1.0218, Validation Loss: 1.0488
# 	 	 Training Acc: 0.6788, Validation Acc: 0.6719
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.7812
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 105000 to /content/checkpoint.pkl
# Iteration 105000, time elapsed: 772.68 seconds
# 	 	 Training Loss: 0.9808, Validation Loss: 1.0292
# 	 	 Training Acc: 0.6884, Validation Acc: 0.6729
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.5625
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 106500 to /content/checkpoint.pkl
# Iteration 106500, time elapsed: 783.65 seconds
# 	 	 Training Loss: 1.0208, Validation Loss: 1.0688
# 	 	 Training Acc: 0.6797, Validation Acc: 0.6646
# 	 	 Last Char Training Acc: 0.6875, Last Char Validation Acc: 0.7500
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 108000 to /content/checkpoint.pkl
# Iteration 108000, time elapsed: 794.77 seconds
# 	 	 Training Loss: 1.0493, Validation Loss: 1.0813
# 	 	 Training Acc: 0.6688, Validation Acc: 0.6636
# 	 	 Last Char Training Acc: 0.7188, Last Char Validation Acc: 0.5938
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 109500 to /content/checkpoint.pkl
# Iteration 109500, time elapsed: 806.04 seconds
# 	 	 Training Loss: 1.0657, Validation Loss: 1.0029
# 	 	 Training Acc: 0.6639, Validation Acc: 0.6871
# 	 	 Last Char Training Acc: 0.6250, Last Char Validation Acc: 0.6875
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 111000 to /content/checkpoint.pkl
# Iteration 111000, time elapsed: 816.92 seconds
# 	 	 Training Loss: 1.0236, Validation Loss: 1.0477
# 	 	 Training Acc: 0.6781, Validation Acc: 0.6644
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.6875
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 112500 to /content/checkpoint.pkl
# Iteration 112500, time elapsed: 827.83 seconds
# 	 	 Training Loss: 1.0030, Validation Loss: 1.0566
# 	 	 Training Acc: 0.6859, Validation Acc: 0.6694
# 	 	 Last Char Training Acc: 0.6562, Last Char Validation Acc: 0.6250
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 114000 to /content/checkpoint.pkl
# Iteration 114000, time elapsed: 839.18 seconds
# 	 	 Training Loss: 1.0149, Validation Loss: 1.0812
# 	 	 Training Acc: 0.6759, Validation Acc: 0.6630
# 	 	 Last Char Training Acc: 0.5938, Last Char Validation Acc: 0.5938
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 115500 to /content/checkpoint.pkl
# Iteration 115500, time elapsed: 850.33 seconds
# 	 	 Training Loss: 0.9827, Validation Loss: 1.0757
# 	 	 Training Acc: 0.6866, Validation Acc: 0.6632
# 	 	 Last Char Training Acc: 0.6562, Last Char Validation Acc: 0.6562
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 117000 to /content/checkpoint.pkl
# Iteration 117000, time elapsed: 861.66 seconds
# 	 	 Training Loss: 1.0808, Validation Loss: 1.0413
# 	 	 Training Acc: 0.6605, Validation Acc: 0.6757
# 	 	 Last Char Training Acc: 0.5938, Last Char Validation Acc: 0.7500
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 118500 to /content/checkpoint.pkl
# Iteration 118500, time elapsed: 872.60 seconds
# 	 	 Training Loss: 1.0047, Validation Loss: 1.0859
# 	 	 Training Acc: 0.6801, Validation Acc: 0.6622
# 	 	 Last Char Training Acc: 0.5312, Last Char Validation Acc: 0.6562
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 120000 to /content/checkpoint.pkl
# Iteration 120000, time elapsed: 883.78 seconds
# 	 	 Training Loss: 1.0400, Validation Loss: 1.0399
# 	 	 Training Acc: 0.6782, Validation Acc: 0.6765
# 	 	 Last Char Training Acc: 0.8125, Last Char Validation Acc: 0.5938
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 121500 to /content/checkpoint.pkl
# Iteration 121500, time elapsed: 894.79 seconds
# 	 	 Training Loss: 1.0276, Validation Loss: 1.0521
# 	 	 Training Acc: 0.6802, Validation Acc: 0.6718
# 	 	 Last Char Training Acc: 0.7812, Last Char Validation Acc: 0.5000
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 123000 to /content/checkpoint.pkl
# Iteration 123000, time elapsed: 905.94 seconds
# 	 	 Training Loss: 1.0108, Validation Loss: 1.0596
# 	 	 Training Acc: 0.6836, Validation Acc: 0.6609
# 	 	 Last Char Training Acc: 0.7812, Last Char Validation Acc: 0.6250
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 124500 to /content/checkpoint.pkl
# Iteration 124500, time elapsed: 916.95 seconds
# 	 	 Training Loss: 1.0060, Validation Loss: 1.0486
# 	 	 Training Acc: 0.6827, Validation Acc: 0.6674
# 	 	 Last Char Training Acc: 0.6875, Last Char Validation Acc: 0.5938
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 126000 to /content/checkpoint.pkl
# Iteration 126000, time elapsed: 927.70 seconds
# 	 	 Training Loss: 0.9901, Validation Loss: 1.0145
# 	 	 Training Acc: 0.6827, Validation Acc: 0.6765
# 	 	 Last Char Training Acc: 0.7188, Last Char Validation Acc: 0.6250
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 127500 to /content/checkpoint.pkl
# Iteration 127500, time elapsed: 938.75 seconds
# 	 	 Training Loss: 1.0009, Validation Loss: 1.0285
# 	 	 Training Acc: 0.6847, Validation Acc: 0.6750
# 	 	 Last Char Training Acc: 0.9375, Last Char Validation Acc: 0.6250
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 129000 to /content/checkpoint.pkl
# Iteration 129000, time elapsed: 949.69 seconds
# 	 	 Training Loss: 0.9697, Validation Loss: 1.0544
# 	 	 Training Acc: 0.6969, Validation Acc: 0.6644
# 	 	 Last Char Training Acc: 0.8438, Last Char Validation Acc: 0.7812
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 130500 to /content/checkpoint.pkl
# Iteration 130500, time elapsed: 960.87 seconds
# 	 	 Training Loss: 1.0277, Validation Loss: 1.0099
# 	 	 Training Acc: 0.6754, Validation Acc: 0.6798
# 	 	 Last Char Training Acc: 0.6875, Last Char Validation Acc: 0.4688
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 132000 to /content/checkpoint.pkl
# Iteration 132000, time elapsed: 971.86 seconds
# 	 	 Training Loss: 1.0416, Validation Loss: 1.0255
# 	 	 Training Acc: 0.6674, Validation Acc: 0.6855
# 	 	 Last Char Training Acc: 0.5938, Last Char Validation Acc: 0.7188
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 133500 to /content/checkpoint.pkl
# Iteration 133500, time elapsed: 982.64 seconds
# 	 	 Training Loss: 1.0104, Validation Loss: 1.0521
# 	 	 Training Acc: 0.6769, Validation Acc: 0.6741
# 	 	 Last Char Training Acc: 0.7188, Last Char Validation Acc: 0.7812
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 135000 to /content/checkpoint.pkl
# Iteration 135000, time elapsed: 993.72 seconds
# 	 	 Training Loss: 0.9869, Validation Loss: 1.0698
# 	 	 Training Acc: 0.6848, Validation Acc: 0.6740
# 	 	 Last Char Training Acc: 0.6875, Last Char Validation Acc: 0.7188
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 136500 to /content/checkpoint.pkl
# Iteration 136500, time elapsed: 1005.03 seconds
# 	 	 Training Loss: 0.9913, Validation Loss: 0.9972
# 	 	 Training Acc: 0.6876, Validation Acc: 0.6903
# 	 	 Last Char Training Acc: 0.5625, Last Char Validation Acc: 0.7812
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 138000 to /content/checkpoint.pkl
# Iteration 138000, time elapsed: 1016.20 seconds
# 	 	 Training Loss: 1.0317, Validation Loss: 1.0560
# 	 	 Training Acc: 0.6741, Validation Acc: 0.6704
# 	 	 Last Char Training Acc: 0.6250, Last Char Validation Acc: 0.5312
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 139500 to /content/checkpoint.pkl
# Iteration 139500, time elapsed: 1027.31 seconds
# 	 	 Training Loss: 1.0200, Validation Loss: 1.0122
# 	 	 Training Acc: 0.6774, Validation Acc: 0.6840
# 	 	 Last Char Training Acc: 0.7188, Last Char Validation Acc: 0.7500
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 141000 to /content/checkpoint.pkl
# Iteration 141000, time elapsed: 1038.10 seconds
# 	 	 Training Loss: 1.0372, Validation Loss: 1.0498
# 	 	 Training Acc: 0.6779, Validation Acc: 0.6781
# 	 	 Last Char Training Acc: 0.7188, Last Char Validation Acc: 0.7500
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 142500 to /content/checkpoint.pkl
# Iteration 142500, time elapsed: 1049.13 seconds
# 	 	 Training Loss: 0.9968, Validation Loss: 1.0400
# 	 	 Training Acc: 0.6865, Validation Acc: 0.6777
# 	 	 Last Char Training Acc: 0.7188, Last Char Validation Acc: 0.7500
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 144000 to /content/checkpoint.pkl
# Iteration 144000, time elapsed: 1060.21 seconds
# 	 	 Training Loss: 0.9683, Validation Loss: 1.0274
# 	 	 Training Acc: 0.6943, Validation Acc: 0.6720
# 	 	 Last Char Training Acc: 0.6562, Last Char Validation Acc: 0.7188
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 145500 to /content/checkpoint.pkl
# Iteration 145500, time elapsed: 1071.04 seconds
# 	 	 Training Loss: 0.9575, Validation Loss: 1.0230
# 	 	 Training Acc: 0.6956, Validation Acc: 0.6812
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.7500
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 147000 to /content/checkpoint.pkl
# Iteration 147000, time elapsed: 1082.10 seconds
# 	 	 Training Loss: 0.9959, Validation Loss: 1.0328
# 	 	 Training Acc: 0.6833, Validation Acc: 0.6787
# 	 	 Last Char Training Acc: 0.7812, Last Char Validation Acc: 0.6562
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 148500 to /content/checkpoint.pkl
# Iteration 148500, time elapsed: 1093.23 seconds
# 	 	 Training Loss: 0.9739, Validation Loss: 1.0063
# 	 	 Training Acc: 0.6863, Validation Acc: 0.6880
# 	 	 Last Char Training Acc: 0.7812, Last Char Validation Acc: 0.7500
# --------------------------------------------------
# [save_checkpoint] Saved checkpoint at step 149999 to /content/checkpoint.pkl
# Iteration 149999, time elapsed: 1104.43 seconds
# 	 	 Training Loss: 1.0112, Validation Loss: 1.0964
# 	 	 Training Acc: 0.6750, Validation Acc: 0.6573
# 	 	 Last Char Training Acc: 0.6562, Last Char Validation Acc: 0.6562
# --------------------------------------------------
# Training completed in 1104.53 seconds.

# %% [markdown]
# ## Plot the training and validation loss curves
#
# After training, we plot the training and validation loss curves to visualize the model's learning progress over time. This plot is saved to the specified output directory, and will be useful to identify if the model converges at first glance. Among all the ablation experiments for that category, we can also compare these curves to see how different configurations affect the learning dynamics.

# %%
# Plot training and validation loss curves
plt.plot(train_step_history, train_loss_history, "-",label='Training Loss', color='blue')
plt.plot(val_step_history, val_loss_history, "-", label='Validation Loss', lw = 2, color='red')
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.legend(loc = "upper right")
plt.title("Training and Validation Loss over Iterations")
plt.legend()
plt.savefig(cwd / "loss_curve.png")
plt.show()

# %% [markdown]
# ## Testing the model on a given prompt
#
# We finally test the trained model by generating text based on a given prompt. The model successfully generates a sequence of characters that continue from the prompt, and we save the generated text to a file for review.

# %%
# Test the model on a given prompt
prompt = "the meaning of life is"
encoded_prompt = fn.encode(prompt, chars_to_int)
context = encoded_prompt[None, :]

B = 1
seed = seed
generate_len = 1000
rng = jax.random.PRNGKey(seed)

output_indices = fn.generate_tokens(
    model=model_obj,
    params=params,
    constants=constants,
    rng=rng,
    context=context,
    length=generate_len,
    block_size=64,
    temperature=0.8,
    sample=True,
    pad_id=None,
    deterministic=True
)

output_indices = np.array(output_indices)  # Convert from JAX array to NumPy array
generated_text = fn.decode(output_indices, int_to_chars)

print("Generated ID Shape:", output_indices.shape)
print("Generated Text:")
print(prompt + generated_text)

generated_text_file = cwd / "generated_text.txt"

with open(generated_text_file, "w") as f:
    f.write(prompt + generated_text)
# Out:
# Generated ID Shape: (1, 1000)
# Generated Text:
# the meaning of life is told to solve a success would take the time to contemplate confine and according to the time of others the title of star gospel of philosophy of nature and gospel of jesus christ of latter day saints in the lithuanians in the various languages the breakdown of china of the mouth of the great derry in a salle of good salle of the sun between the two stripes reflect the flavor of the frequency of dye in an additional flavor from the frequency of dyeing the node is the number of dyes man can be understood the number of batters loving a large reproduction of the creature and his acting synagogues produced the creature when this every day he was not known as his student against him in one zero three four was joining his monument to the one st century was also a professor in the early one nine th century the netherlands ruled and spain in nine four three bc to believe that keaton is the least of the common town of eastern asia the first community of the commonwealth of timor which eventuall
