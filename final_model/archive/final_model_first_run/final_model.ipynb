# %% [markdown]
# # Final Model
#
# After completing all preliminary experiments and hyperparameter tuning, we proceed to train our final character-level language model using the best-found hyperparameters. The following sections detail the training process, evaluation metrics, and visualizations of the model's performance. We ensure to save all relevant results, checkpoints and plots to local storage as well as to Google Drive for future reference and more importantly backup, just in case of any unforeseen runtime disconnections.

# %%
import matplotlib.pyplot as plt
import optax
import sys
import jax
import time
import os
import numpy as np

import setup_utils as su_utils
import training_utils as tr_utils
# Out:
# /usr/local/lib/python3.12/dist-packages/jax/_src/cloud_tpu_init.py:86: UserWarning: Transparent hugepages are not enabled. TPU runtime startup and shutdown time should be significantly improved on TPU v5e and newer. If not already set, you may need to enable transparent hugepages in your VM image (sudo sh -c "echo always > /sys/kernel/mm/transparent_hugepage/enabled")
#   warnings.warn(

# %%
from google.colab import drive
drive.mount('/content/drive')

# Set up a backup drive and download directory
DRIVE_BACKUP_DIR = "/content/drive/MyDrive/final_model_results"
os.makedirs(DRIVE_BACKUP_DIR, exist_ok=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Load the Experiment Setup

# %% [markdown]
# ## Set the relevant directory paths & log files
#
# Here, we set the necessary directories and output paths for saving model checkpoints and log results.

# %%
# Input name of train & test files
train_file = "./text8_train.txt"
test_file = "./text8_test.txt"

# Input name of config and log files
config_file = "./config.json"
training_log_file = "./training_results.log"
validation_log_file = "./validation_results.log"
test_log_file = "./test_results.log"
checkpoint_file = "./checkpoint.pkl"

# %%
# Set up directories and log files
su_utils.setup(training_log_file, validation_log_file, test_log_file)
# Out:
# [initialize_training_log] Initialized training log file at ./training_results.log
# [initialize_validation_log] Initialized validation log file at ./validation_results.log
# [initialize_test_log] Initialized test log file at ./test_results.log

# %% [markdown]
# ## Load the experiment configurations
#
# Prior to running this notebook, the experiment configurations will be set in a 'config.json' file, which will be loaded to set the model hyperparameters and training settings.

# %%
name, description, seed, model, training, throughput = su_utils.load_config("./config.json")

print(f"We will be {description}")
# Out:
# [load_config] Loaded configuration from ./config.json
# We will be Training the final character-level LLM with chosen architecture and hyperparameters.

# %%
# Set up Model Configurations
vocab_size, d_model, n_heads = model['vocab_size'], model['d_model'], model['n_heads']
n_layers, mlp_ratio, seq_len = model['n_layers'], model['mlp_ratio'], model['seq_len']

dropout, pos_encoding, attention_type = model['dropout'], model['pos_encoding'], model['attention_type']
use_auxiliary_loss, aux_heads, aux_weight = model['use_auxiliary_loss'], model['aux_heads'], model['aux_weight']
loss_type, mixed_precision = model['loss_type'], model['mixed_precision']

print(
    f"Model configurations set: \n"
    f"d_model={d_model}, n_heads={n_heads}, n_layers={n_layers}, seq_len={seq_len}\n"
    f"n_layers={n_layers}, mlp_ratio={mlp_ratio}, dropout={dropout}\n"
)

# Set up Training Configurations
val_fraction, batch_size = training['val_fraction'], training['batch_size']
learning_rate, weight_decay, lr_schedule = training['learning_rate'], training['weight_decay'], training['lr_schedule']
optimizer_type, warmup_ratio, label_smoothing, grad_clip = training['optimizer'], training['warmup_ratio'], float(training['label_smoothing']), training['grad_clip']

print(
    f"Training configurations set: \n"
    f"batch_size={batch_size}, learning_rate={learning_rate}, weight_decay={weight_decay}\n"
    f"optimizer={optimizer_type}, lr_schedule={lr_schedule}, warmup_ratio={warmup_ratio}\n"
)

# Set up Throughput Configurations
max_test_iters, max_test_time = throughput['max_test_iters'], throughput['max_test_time_in_seconds']
compute_budget_hours = throughput['compute_budget_hours']

print(
    f"Throughput configurations set: \n"
    f"max_test_iters={max_test_iters}iters, max_test_time={max_test_time}s, compute_budget_hours={compute_budget_hours}H ({compute_budget_hours*3600:.2f}s)\n"
)
# Out:
# Model configurations set:
# d_model=256, n_heads=4, n_layers=6, seq_len=256
# n_layers=6, mlp_ratio=4, dropout=0.0
#
# Training configurations set:
# batch_size=32, learning_rate=0.0005442555534215833, weight_decay=0.05
# optimizer=adam, lr_schedule=cosine, warmup_ratio=none
#
# Throughput configurations set:
# max_test_iters=2000iters, max_test_time=60s, compute_budget_hours=7H (25200.00s)

# %% [markdown]
# # Loading the Data
#
# The text8 dataset is used, which has 100M characters of text data from Wikipedia articles. It contains only lowercase letters and spaces, and is already pre-split into 90M characters for training and 10M characters for testing.

# %%
train_text, test_text, chars_to_int, int_to_chars = su_utils.load_dataset(train_file, test_file)
# Out:
# [load_dataset] Loaded training text from ./text8_train.txt. Length: 90,000,000 characters.
#
# [load_dataset] Loaded testing text from ./text8_test.txt. Length: 5,000,000 characters.
#
# [load_dataset] First 100 characters of training text:
#  anarchism originated as a term of abuse first used against early working class radicals including t
#
# [load_dataset] First 100 characters of testing text:
# be ejected and hold it there examine the chamber to ensure it is clear allow the action to go forwar
#
# [load_dataset] Created character mappings. Vocabulary size: 27

# %% [markdown]
# We further split the training data into a training set and a validation set to monitor the model's performance during training, in accordance to the validation fraction specified in our configuration file (10%)

# %%
train_text, val_text = su_utils.split_train_val(train_text, val_fraction=val_fraction)
# Out:
# [split_train_val] Training text length: 89,099,996 characters.
# [split_train_val] Validation text length: 900,004 characters.

# %% [markdown]
# We then encode the text data into integer format for model training. Each unique character is mapped to a unique integer index.

# %%
# Encode the train, val, test texts
train_data = tr_utils.encode(train_text, chars_to_int)
val_data = tr_utils.encode(val_text, chars_to_int)
test_data = tr_utils.encode(test_text, chars_to_int)

# %% [markdown]
# # Model Initialisation

# %% [markdown]
# ## Model Setup
#
# We intialise our model with the following parameters in accordance to our configuration file.
# Based on these parameters, our model has approximately ~4.2M parameters.

# %%
# Define the model params
rng = jax.random.PRNGKey(seed)

model_obj, params, constants = tr_utils.create_train_state(
        rng,
        vocab_size = vocab_size,
        d_model = d_model,
        n_heads = n_heads,
        n_layers = n_layers,
        mlp_ratio = mlp_ratio,
        seq_len = seq_len,
        dropout = dropout,
        aux_loss = use_auxiliary_loss,
        num_aux_heads = aux_heads,
        mixed_precision = mixed_precision,
        attention_type = attention_type,
        pos_encoding = pos_encoding
)
# Out:
# [create_train_state] Model initialized with 4,160,768 parameters.

# %% [markdown]
# We perform a sanity check by running a single forward pass with random input data to ensure the model is functioning as expected.

# %%
# SANITY CHECK: Test the model forward pass
B, T = 2, 8  # Batch size and sequence length
batch = jax.random.randint(key = rng, shape = (B, T), minval = 0, maxval = vocab_size)

variables = {"params": params, "constants": constants}
output = model_obj.apply(variables, batch, deterministic=False, rngs={"dropout": rng})

print("Logits shape:", output["logits"].shape)  # Expected: (B, T, vocab_size)

if output["logits"].shape[0] == B and output["logits"].shape[1] == T and output["logits"].shape[2] == vocab_size:
    print("Sanity check passed: Model forward pass output shape is correct.")
else:
    print("Sanity check failed: Model forward pass output shape is incorrect.")
# Out:
# Logits shape: (2, 8, 27)
# Sanity check passed: Model forward pass output shape is correct.

# %% [markdown]
# ## Determine maximum permissible training steps
#
# Taking into account possible compute limitations, we perform a preliminary calculation to determine the maximum number of training steps we can perform based on the throughput of our model and the total training time available. For this preliminary test, the default maximum training time is 60 seconds, and commpute budget hours is 7 hours.
#
# Based on the throughput calculated from the preliminary test, the estimated maximum no. of training steps we can perform within this compute budget is ~2M. To ensure we keep within the budget, we set the maximum training steps to be 2M.

# %%
# Create a dummy optimizer and opt_state for throughput calculation
dummy_optimizer, dummy_opt_state = tr_utils.create_dummy_optimizer(
    learning_rate = learning_rate,
    optimizer_type = optimizer_type,
    weight_decay = weight_decay,
    params = params
)

# Determining how many steps we can run in a reasonable time
_ , max_steps = tr_utils.calculate_throughput(
    max_test_iters = max_test_iters,
    max_test_time = max_test_time,
    model = model_obj,
    params = params,
    opt_state = dummy_opt_state,
    optimizer = dummy_optimizer,
    rng = rng,
    batch_size = batch_size,
    seq_len = seq_len,
    compute_budget = compute_budget_hours,
    train_data = train_data,
    loss_type = loss_type,
    aux_loss = use_auxiliary_loss,
    aux_weight = aux_weight,
    constants = constants,
    label_smoothing = label_smoothing
)
# Out:
# Benchmark completed in 25.09 seconds.
# Total tokens processed: 16384000
# Throughput: 653090.58 tokens/second
# Estimated max steps within compute budget: 2009018.0

# %% [markdown]
# ## Initialise the optimizer
#
# In this section, we set up the optimizer for training our model in accordance to our configuration file.

# %%
iter_max = 2000000 # Set max iterations in accordance to compute budget
# iter_max = int(max_steps * 0.9)  # If we want to use 90% of the computed max steps
print(f"Setting iter_max = {iter_max}.\n")

optimizer, opt_state = tr_utils.initialize_optimizer(
    params=params,
    iter_max=iter_max,
    optimizer_type=optimizer_type,
    lr_schedule=lr_schedule,
    learning_rate=learning_rate,
    weight_decay=weight_decay,
    warmup_ratio=warmup_ratio,
    grad_clip=grad_clip
)
# Out:
# Setting iter_max = 2000000.
#
# [initialize_optimizer] Initialized adam optimizer configurations:learning_rate_schedule=cosine, learning_rate=0.0005442555534215833, weight_decay=0.05, grad_clip=noneweight_decay applied: no, grad_clip applied: nowarmup_ratio=none, total_iterations=2000000

# %% [markdown]
# # Model Training & Evaluation

# %% [markdown]
# ## Training the model
#
# Now, we proceed to train the model over the determined number of training iterations. During training, we monitor the training loss and periodically evaluate the model on the validation set to track its performance. We also make sure to record the time taken for training to ensure it stays within our compute budget.

# %%
log_val_every = max(1, iter_max // 100) # Determine Validation logging frequency
save_checkpoint_every = max(1, iter_max // 20) # Determine Checkpoint saving frequency
upload_to_drive_every = max(1, iter_max // 20) # Determine Drive upload frequency
num_val_batches = 5  # Number of validation batches to average over

# To track training and validation loss, as well as time taken
train_loss_history = []
val_loss_history = []
train_acc_history = []
val_acc_history = []
last_char_train_acc_history = []
last_char_val_acc_history = []
train_step_history = list(range(iter_max))
val_step_history = []

# Load checkpoint if it exists
params, opt_state, constants, start_iter = su_utils.load_checkpoint(
    checkpoint_file,
    params,
    constants,
    opt_state
)
# Out:
# [load_checkpoint] No checkpoint found at ./checkpoint.pkl
# [load_checkpoint] Starting training as per normal.

# %% [markdown]
# We then train the model and log the training and validation losses for analysis. All relevant results, checkpoints and plots are saved periodically to local storage as well as to Google Drive for future reference and backup.

# %%
if start_iter > 0:
        print(f"Resuming training from iteration = {start_iter}.")
else:
        print("Starting training from iteration = 0.")

time_start = time.time()
best_val_loss = float('inf')

for it in range(start_iter, iter_max):

    # get a batch of data
    inputs, targets = tr_utils.get_batch(train_data, batch_size, seq_len)

    # Perform a training step
    rng, sub = jax.random.split(rng)
    new_params, new_opt_state, metrics = tr_utils.train_step(
            model = model_obj,
            params = params,
            constants=constants,
            opt_state = opt_state,
            x = inputs,
            y = targets,
            tx = optimizer,
            rng = sub,
            loss_type = loss_type,
            aux_loss = use_auxiliary_loss,
            aux_weight = aux_weight,
            label_smoothing = label_smoothing
    )

    # Update parameters and optimizer state
    params = new_params
    opt_state = new_opt_state

    # Record training metrics
    acc = metrics['acc']
    loss = metrics['loss']
    last_char_acc = metrics['acc_last']
    train_time = time.time() - time_start

    train_loss_history.append(loss)
    train_acc_history.append(acc)
    last_char_train_acc_history.append(last_char_acc)

    su_utils.update_training_log(
        log_path = "training_results.log",
        step = it,
        train_loss = loss,
        train_time = train_time,
        train_acc = acc,
        last_char_acc = last_char_acc
        )

    # Upload training log to Drive at regular intervals
    if (it % upload_to_drive_every) == 0 or (it == iter_max - 1):
        su_utils.save_to_drive(
            drive_backup_dir=DRIVE_BACKUP_DIR,
            file_name="training_results.log"
        )

    # Perform validation and checkpoint saving at specified intervals
    if (it % log_val_every) == 0 or (it == iter_max - 1): # Print every 1% of iterations

        val_losses = []
        val_accs = []
        val_last_char_accs = []

        for _ in range(num_val_batches):
            # Compute the loss on validation set
            batch_size_val = batch_size
            seq_len_val = seq_len
            val_inputs, val_targets = tr_utils.get_batch(val_data, batch_size_val, seq_len_val)

            val_out = model_obj.apply({"params": params, "constants": constants}, val_inputs, deterministic=True, rngs={"dropout": rng})
            val_logits = val_out["logits"]
            val_aux_logits = val_out.get('aux_logits', None)

            val_loss, val_metrics = tr_utils.loss_and_metrics(
                logits = val_logits,
                targets = val_targets,
                loss_type = loss_type,
                aux_loss = use_auxiliary_loss,
                aux_logits = val_aux_logits,
                aux_weight = aux_weight,
                label_smoothing = label_smoothing
            )

            # Record validation loss and time
            val_acc = val_metrics['acc']
            last_char_acc_val = val_metrics['acc_last']

            # Add validation metrics to lists
            val_losses.append(val_loss)
            val_accs.append(val_acc)
            val_last_char_accs.append(last_char_acc_val)

        # Compute average validation metrics
        val_loss = np.mean(val_losses)
        val_acc = np.mean(val_accs)
        last_char_acc_val = np.mean(val_last_char_accs)

        # Record validation loss and time
        val_loss_history.append(val_loss)
        val_acc_history.append(val_acc)
        last_char_val_acc_history.append(last_char_acc_val)
        time_elapsed = time.time() - time_start
        val_step_history.append(it)

        su_utils.update_validation_log(
            log_path = "validation_results.log",
            step = it,
            val_loss = val_loss,
            val_time = time_elapsed,
            val_acc = val_acc,
            last_char_val_acc = last_char_acc_val
        )

        # Upload validation log to Drive at regular intervals
        su_utils.save_to_drive(
            drive_backup_dir=DRIVE_BACKUP_DIR,
            file_name="validation_results.log"
        )

        # Save checkpoint at regular intervals
        if ((it % save_checkpoint_every) == 0 or (it == iter_max - 1)) and (val_loss - 0.005 < best_val_loss):

            # Save checkpoint in local directory
            su_utils.save_checkpoint(
                checkpoint_path = checkpoint_file,
                params = params,
                constants = constants,
                opt_state = opt_state,
                step = it,
                time_elapsed = time_elapsed
            )

            # Save checkpoint to Drive
            su_utils.save_to_drive(
                drive_backup_dir=DRIVE_BACKUP_DIR,
                file_name=checkpoint_file.split("/")[-1]
            )

            best_val_loss = val_loss

        # Print training and validation metrics
        print(f"Iteration {it}, time elapsed: {time_elapsed:.2f} seconds")
        print(f"\t \t Training Loss: {loss:.4f}, Validation Loss: {val_loss:.4f}")
        print(f"\t \t Training Acc: {acc:.4f}, Validation Acc: {val_acc:.4f}")
        print(f"\t \t Last Char Training Acc: {last_char_acc:.4f}, Last Char Validation Acc: {last_char_acc_val:.4f}")
        print("-" * 50)

print(f"Training completed in {time.time() - time_start:.2f} seconds.")
# Out:
# Starting training from iteration = 0.
# [save_to_drive] Successfully saved training_results.log to /content/drive/MyDrive/final_model_results
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# [save_checkpoint] Saved checkpoint at step 0 to ./checkpoint.pkl
# [save_to_drive] Successfully saved checkpoint.pkl to /content/drive/MyDrive/final_model_results
# Iteration 0, time elapsed: 23.47 seconds
# 	 	 Training Loss: 3.7383, Validation Loss: 3.9986
# 	 	 Training Acc: 0.0593, Validation Acc: 0.1688
# 	 	 Last Char Training Acc: 0.0625, Last Char Validation Acc: 0.1187
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 20000, time elapsed: 166.78 seconds
# 	 	 Training Loss: 1.1356, Validation Loss: 1.1294
# 	 	 Training Acc: 0.6411, Validation Acc: 0.6455
# 	 	 Last Char Training Acc: 0.5000, Last Char Validation Acc: 0.6750
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 40000, time elapsed: 306.96 seconds
# 	 	 Training Loss: 0.9981, Validation Loss: 1.0861
# 	 	 Training Acc: 0.6827, Validation Acc: 0.6565
# 	 	 Last Char Training Acc: 0.6875, Last Char Validation Acc: 0.6625
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 60000, time elapsed: 451.82 seconds
# 	 	 Training Loss: 0.9977, Validation Loss: 1.0488
# 	 	 Training Acc: 0.6887, Validation Acc: 0.6730
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.7250
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 80000, time elapsed: 594.72 seconds
# 	 	 Training Loss: 0.9667, Validation Loss: 1.0572
# 	 	 Training Acc: 0.6946, Validation Acc: 0.6680
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.6625
# --------------------------------------------------
# [save_to_drive] Successfully saved training_results.log to /content/drive/MyDrive/final_model_results
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# [save_checkpoint] Saved checkpoint at step 100000 to ./checkpoint.pkl
# [save_to_drive] Successfully saved checkpoint.pkl to /content/drive/MyDrive/final_model_results
# Iteration 100000, time elapsed: 739.96 seconds
# 	 	 Training Loss: 0.9798, Validation Loss: 1.0632
# 	 	 Training Acc: 0.6959, Validation Acc: 0.6674
# 	 	 Last Char Training Acc: 0.5938, Last Char Validation Acc: 0.6750
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 120000, time elapsed: 885.98 seconds
# 	 	 Training Loss: 1.0342, Validation Loss: 1.0574
# 	 	 Training Acc: 0.6748, Validation Acc: 0.6681
# 	 	 Last Char Training Acc: 0.5312, Last Char Validation Acc: 0.7125
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 140000, time elapsed: 1031.97 seconds
# 	 	 Training Loss: 0.9863, Validation Loss: 1.0325
# 	 	 Training Acc: 0.6952, Validation Acc: 0.6754
# 	 	 Last Char Training Acc: 0.6875, Last Char Validation Acc: 0.7188
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 160000, time elapsed: 1176.31 seconds
# 	 	 Training Loss: 1.0420, Validation Loss: 1.0244
# 	 	 Training Acc: 0.6736, Validation Acc: 0.6779
# 	 	 Last Char Training Acc: 0.5938, Last Char Validation Acc: 0.7312
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 180000, time elapsed: 1321.05 seconds
# 	 	 Training Loss: 0.9772, Validation Loss: 1.0105
# 	 	 Training Acc: 0.6896, Validation Acc: 0.6844
# 	 	 Last Char Training Acc: 0.8125, Last Char Validation Acc: 0.7125
# --------------------------------------------------
# [save_to_drive] Successfully saved training_results.log to /content/drive/MyDrive/final_model_results
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# [save_checkpoint] Saved checkpoint at step 200000 to ./checkpoint.pkl
# [save_to_drive] Successfully saved checkpoint.pkl to /content/drive/MyDrive/final_model_results
# Iteration 200000, time elapsed: 1465.35 seconds
# 	 	 Training Loss: 0.9785, Validation Loss: 1.0414
# 	 	 Training Acc: 0.6941, Validation Acc: 0.6731
# 	 	 Last Char Training Acc: 0.7188, Last Char Validation Acc: 0.7125
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 220000, time elapsed: 1612.77 seconds
# 	 	 Training Loss: 1.0153, Validation Loss: 1.0114
# 	 	 Training Acc: 0.6865, Validation Acc: 0.6837
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.7000
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 240000, time elapsed: 1758.60 seconds
# 	 	 Training Loss: 0.9771, Validation Loss: 1.0247
# 	 	 Training Acc: 0.6970, Validation Acc: 0.6787
# 	 	 Last Char Training Acc: 0.8125, Last Char Validation Acc: 0.7500
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 260000, time elapsed: 1905.49 seconds
# 	 	 Training Loss: 0.9235, Validation Loss: 1.0125
# 	 	 Training Acc: 0.7153, Validation Acc: 0.6832
# 	 	 Last Char Training Acc: 0.5000, Last Char Validation Acc: 0.7188
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 280000, time elapsed: 2052.85 seconds
# 	 	 Training Loss: 0.9416, Validation Loss: 1.0103
# 	 	 Training Acc: 0.7029, Validation Acc: 0.6860
# 	 	 Last Char Training Acc: 0.6875, Last Char Validation Acc: 0.7125
# --------------------------------------------------
# [save_to_drive] Successfully saved training_results.log to /content/drive/MyDrive/final_model_results
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# [save_checkpoint] Saved checkpoint at step 300000 to ./checkpoint.pkl
# [save_to_drive] Successfully saved checkpoint.pkl to /content/drive/MyDrive/final_model_results
# Iteration 300000, time elapsed: 2198.53 seconds
# 	 	 Training Loss: 0.9614, Validation Loss: 1.0128
# 	 	 Training Acc: 0.6982, Validation Acc: 0.6832
# 	 	 Last Char Training Acc: 0.7812, Last Char Validation Acc: 0.6812
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 320000, time elapsed: 2344.34 seconds
# 	 	 Training Loss: 0.9993, Validation Loss: 0.9903
# 	 	 Training Acc: 0.6879, Validation Acc: 0.6913
# 	 	 Last Char Training Acc: 0.7188, Last Char Validation Acc: 0.7188
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 340000, time elapsed: 2490.18 seconds
# 	 	 Training Loss: 1.0045, Validation Loss: 1.0146
# 	 	 Training Acc: 0.6804, Validation Acc: 0.6856
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.6750
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 360000, time elapsed: 2635.93 seconds
# 	 	 Training Loss: 0.9768, Validation Loss: 1.0235
# 	 	 Training Acc: 0.6940, Validation Acc: 0.6847
# 	 	 Last Char Training Acc: 0.7188, Last Char Validation Acc: 0.6750
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 380000, time elapsed: 2781.65 seconds
# 	 	 Training Loss: 0.9665, Validation Loss: 1.0198
# 	 	 Training Acc: 0.6956, Validation Acc: 0.6817
# 	 	 Last Char Training Acc: 0.7812, Last Char Validation Acc: 0.7000
# --------------------------------------------------
# [save_to_drive] Successfully saved training_results.log to /content/drive/MyDrive/final_model_results
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# [save_checkpoint] Saved checkpoint at step 400000 to ./checkpoint.pkl
# [save_to_drive] Successfully saved checkpoint.pkl to /content/drive/MyDrive/final_model_results
# Iteration 400000, time elapsed: 2927.95 seconds
# 	 	 Training Loss: 0.9722, Validation Loss: 0.9907
# 	 	 Training Acc: 0.6880, Validation Acc: 0.6905
# 	 	 Last Char Training Acc: 0.6562, Last Char Validation Acc: 0.7125
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 420000, time elapsed: 3073.62 seconds
# 	 	 Training Loss: 0.9561, Validation Loss: 1.0022
# 	 	 Training Acc: 0.6965, Validation Acc: 0.6866
# 	 	 Last Char Training Acc: 0.6250, Last Char Validation Acc: 0.7000
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 440000, time elapsed: 3223.89 seconds
# 	 	 Training Loss: 0.9554, Validation Loss: 0.9888
# 	 	 Training Acc: 0.7050, Validation Acc: 0.6923
# 	 	 Last Char Training Acc: 0.8438, Last Char Validation Acc: 0.7188
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 460000, time elapsed: 3370.93 seconds
# 	 	 Training Loss: 0.9196, Validation Loss: 0.9782
# 	 	 Training Acc: 0.7140, Validation Acc: 0.6955
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.7437
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 480000, time elapsed: 3517.88 seconds
# 	 	 Training Loss: 0.9444, Validation Loss: 1.0046
# 	 	 Training Acc: 0.7037, Validation Acc: 0.6873
# 	 	 Last Char Training Acc: 0.7188, Last Char Validation Acc: 0.7375
# --------------------------------------------------
# [save_to_drive] Successfully saved training_results.log to /content/drive/MyDrive/final_model_results
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# [save_checkpoint] Saved checkpoint at step 500000 to ./checkpoint.pkl
# [save_to_drive] Successfully saved checkpoint.pkl to /content/drive/MyDrive/final_model_results
# Iteration 500000, time elapsed: 3664.28 seconds
# 	 	 Training Loss: 0.9132, Validation Loss: 0.9808
# 	 	 Training Acc: 0.7140, Validation Acc: 0.6946
# 	 	 Last Char Training Acc: 0.7188, Last Char Validation Acc: 0.7312
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 520000, time elapsed: 3815.02 seconds
# 	 	 Training Loss: 0.9588, Validation Loss: 1.0016
# 	 	 Training Acc: 0.6924, Validation Acc: 0.6915
# 	 	 Last Char Training Acc: 0.5312, Last Char Validation Acc: 0.7375
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 540000, time elapsed: 3962.32 seconds
# 	 	 Training Loss: 0.9372, Validation Loss: 1.0065
# 	 	 Training Acc: 0.7074, Validation Acc: 0.6863
# 	 	 Last Char Training Acc: 0.6562, Last Char Validation Acc: 0.6625
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 560000, time elapsed: 4105.51 seconds
# 	 	 Training Loss: 0.9494, Validation Loss: 1.0353
# 	 	 Training Acc: 0.7020, Validation Acc: 0.6810
# 	 	 Last Char Training Acc: 0.5938, Last Char Validation Acc: 0.7000
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 580000, time elapsed: 4251.97 seconds
# 	 	 Training Loss: 0.9523, Validation Loss: 0.9993
# 	 	 Training Acc: 0.7004, Validation Acc: 0.6892
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.6812
# --------------------------------------------------
# [save_to_drive] Successfully saved training_results.log to /content/drive/MyDrive/final_model_results
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 600000, time elapsed: 4401.33 seconds
# 	 	 Training Loss: 0.9652, Validation Loss: 0.9869
# 	 	 Training Acc: 0.7000, Validation Acc: 0.6907
# 	 	 Last Char Training Acc: 0.5625, Last Char Validation Acc: 0.7750
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 620000, time elapsed: 4551.72 seconds
# 	 	 Training Loss: 0.9560, Validation Loss: 1.0194
# 	 	 Training Acc: 0.6997, Validation Acc: 0.6844
# 	 	 Last Char Training Acc: 0.7812, Last Char Validation Acc: 0.6687
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 640000, time elapsed: 4698.20 seconds
# 	 	 Training Loss: 0.8948, Validation Loss: 0.9910
# 	 	 Training Acc: 0.7173, Validation Acc: 0.6907
# 	 	 Last Char Training Acc: 0.6875, Last Char Validation Acc: 0.6750
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 660000, time elapsed: 4842.24 seconds
# 	 	 Training Loss: 0.9329, Validation Loss: 0.9786
# 	 	 Training Acc: 0.7069, Validation Acc: 0.6979
# 	 	 Last Char Training Acc: 0.7188, Last Char Validation Acc: 0.7188
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 680000, time elapsed: 4989.36 seconds
# 	 	 Training Loss: 0.9931, Validation Loss: 0.9971
# 	 	 Training Acc: 0.6938, Validation Acc: 0.6905
# 	 	 Last Char Training Acc: 0.6562, Last Char Validation Acc: 0.7000
# --------------------------------------------------
# [save_to_drive] Successfully saved training_results.log to /content/drive/MyDrive/final_model_results
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 700000, time elapsed: 5132.96 seconds
# 	 	 Training Loss: 0.9256, Validation Loss: 0.9983
# 	 	 Training Acc: 0.7123, Validation Acc: 0.6909
# 	 	 Last Char Training Acc: 0.8750, Last Char Validation Acc: 0.6687
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 720000, time elapsed: 5277.14 seconds
# 	 	 Training Loss: 0.9234, Validation Loss: 1.0112
# 	 	 Training Acc: 0.7137, Validation Acc: 0.6864
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.7312
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 740000, time elapsed: 5425.77 seconds
# 	 	 Training Loss: 0.9419, Validation Loss: 0.9975
# 	 	 Training Acc: 0.7063, Validation Acc: 0.6923
# 	 	 Last Char Training Acc: 0.7812, Last Char Validation Acc: 0.7063
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 760000, time elapsed: 5571.58 seconds
# 	 	 Training Loss: 0.9450, Validation Loss: 0.9912
# 	 	 Training Acc: 0.7084, Validation Acc: 0.6913
# 	 	 Last Char Training Acc: 0.6875, Last Char Validation Acc: 0.7250
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 780000, time elapsed: 5718.18 seconds
# 	 	 Training Loss: 0.9727, Validation Loss: 1.0229
# 	 	 Training Acc: 0.6931, Validation Acc: 0.6838
# 	 	 Last Char Training Acc: 0.7812, Last Char Validation Acc: 0.7063
# --------------------------------------------------
# [save_to_drive] Successfully saved training_results.log to /content/drive/MyDrive/final_model_results
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# [save_checkpoint] Saved checkpoint at step 800000 to ./checkpoint.pkl
# [save_to_drive] Successfully saved checkpoint.pkl to /content/drive/MyDrive/final_model_results
# Iteration 800000, time elapsed: 5863.77 seconds
# 	 	 Training Loss: 0.9460, Validation Loss: 0.9664
# 	 	 Training Acc: 0.7069, Validation Acc: 0.7002
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.7750
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 820000, time elapsed: 6006.86 seconds
# 	 	 Training Loss: 0.9560, Validation Loss: 0.9990
# 	 	 Training Acc: 0.7000, Validation Acc: 0.6908
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.6875
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 840000, time elapsed: 6149.18 seconds
# 	 	 Training Loss: 0.9302, Validation Loss: 1.0157
# 	 	 Training Acc: 0.7101, Validation Acc: 0.6840
# 	 	 Last Char Training Acc: 0.6875, Last Char Validation Acc: 0.7125
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 860000, time elapsed: 6291.06 seconds
# 	 	 Training Loss: 0.8871, Validation Loss: 1.0102
# 	 	 Training Acc: 0.7230, Validation Acc: 0.6899
# 	 	 Last Char Training Acc: 0.8438, Last Char Validation Acc: 0.5500
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 880000, time elapsed: 6437.51 seconds
# 	 	 Training Loss: 0.9563, Validation Loss: 0.9973
# 	 	 Training Acc: 0.6981, Validation Acc: 0.6913
# 	 	 Last Char Training Acc: 0.8125, Last Char Validation Acc: 0.6875
# --------------------------------------------------
# [save_to_drive] Successfully saved training_results.log to /content/drive/MyDrive/final_model_results
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 900000, time elapsed: 6580.39 seconds
# 	 	 Training Loss: 0.9350, Validation Loss: 1.0209
# 	 	 Training Acc: 0.7021, Validation Acc: 0.6848
# 	 	 Last Char Training Acc: 0.6875, Last Char Validation Acc: 0.6313
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 920000, time elapsed: 6722.80 seconds
# 	 	 Training Loss: 0.9316, Validation Loss: 1.0115
# 	 	 Training Acc: 0.7058, Validation Acc: 0.6863
# 	 	 Last Char Training Acc: 0.8438, Last Char Validation Acc: 0.7188
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 940000, time elapsed: 6865.21 seconds
# 	 	 Training Loss: 0.9528, Validation Loss: 1.0023
# 	 	 Training Acc: 0.6997, Validation Acc: 0.6908
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.6938
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 960000, time elapsed: 7005.27 seconds
# 	 	 Training Loss: 0.9090, Validation Loss: 0.9858
# 	 	 Training Acc: 0.7133, Validation Acc: 0.6972
# 	 	 Last Char Training Acc: 0.7812, Last Char Validation Acc: 0.7437
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 980000, time elapsed: 7149.15 seconds
# 	 	 Training Loss: 0.9006, Validation Loss: 1.0022
# 	 	 Training Acc: 0.7173, Validation Acc: 0.6875
# 	 	 Last Char Training Acc: 0.8438, Last Char Validation Acc: 0.6438
# --------------------------------------------------
# [save_to_drive] Successfully saved training_results.log to /content/drive/MyDrive/final_model_results
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1000000, time elapsed: 7289.46 seconds
# 	 	 Training Loss: 0.9119, Validation Loss: 0.9927
# 	 	 Training Acc: 0.7134, Validation Acc: 0.6907
# 	 	 Last Char Training Acc: 0.7188, Last Char Validation Acc: 0.7188
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1020000, time elapsed: 7429.57 seconds
# 	 	 Training Loss: 0.9542, Validation Loss: 1.0122
# 	 	 Training Acc: 0.7043, Validation Acc: 0.6894
# 	 	 Last Char Training Acc: 0.6875, Last Char Validation Acc: 0.7000
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1040000, time elapsed: 7578.75 seconds
# 	 	 Training Loss: 0.8836, Validation Loss: 0.9937
# 	 	 Training Acc: 0.7266, Validation Acc: 0.6971
# 	 	 Last Char Training Acc: 0.8125, Last Char Validation Acc: 0.6687
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1060000, time elapsed: 7722.37 seconds
# 	 	 Training Loss: 0.9511, Validation Loss: 1.0083
# 	 	 Training Acc: 0.6985, Validation Acc: 0.6890
# 	 	 Last Char Training Acc: 0.8125, Last Char Validation Acc: 0.7063
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1080000, time elapsed: 7865.03 seconds
# 	 	 Training Loss: 0.9311, Validation Loss: 0.9961
# 	 	 Training Acc: 0.7065, Validation Acc: 0.6922
# 	 	 Last Char Training Acc: 0.8438, Last Char Validation Acc: 0.7063
# --------------------------------------------------
# [save_to_drive] Successfully saved training_results.log to /content/drive/MyDrive/final_model_results
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1100000, time elapsed: 8008.02 seconds
# 	 	 Training Loss: 0.9234, Validation Loss: 0.9903
# 	 	 Training Acc: 0.7081, Validation Acc: 0.6930
# 	 	 Last Char Training Acc: 0.7188, Last Char Validation Acc: 0.7125
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1120000, time elapsed: 8151.21 seconds
# 	 	 Training Loss: 0.8867, Validation Loss: 0.9972
# 	 	 Training Acc: 0.7156, Validation Acc: 0.6922
# 	 	 Last Char Training Acc: 0.8125, Last Char Validation Acc: 0.6438
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1140000, time elapsed: 8295.03 seconds
# 	 	 Training Loss: 0.9192, Validation Loss: 1.0127
# 	 	 Training Acc: 0.7141, Validation Acc: 0.6872
# 	 	 Last Char Training Acc: 0.6250, Last Char Validation Acc: 0.7125
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1160000, time elapsed: 8437.92 seconds
# 	 	 Training Loss: 0.9238, Validation Loss: 0.9983
# 	 	 Training Acc: 0.7078, Validation Acc: 0.6888
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.7250
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1180000, time elapsed: 8581.38 seconds
# 	 	 Training Loss: 0.9258, Validation Loss: 0.9840
# 	 	 Training Acc: 0.7142, Validation Acc: 0.6954
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.7188
# --------------------------------------------------
# [save_to_drive] Successfully saved training_results.log to /content/drive/MyDrive/final_model_results
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1200000, time elapsed: 8724.38 seconds
# 	 	 Training Loss: 0.9069, Validation Loss: 0.9911
# 	 	 Training Acc: 0.7239, Validation Acc: 0.6913
# 	 	 Last Char Training Acc: 0.6250, Last Char Validation Acc: 0.6812
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1220000, time elapsed: 8873.81 seconds
# 	 	 Training Loss: 0.8918, Validation Loss: 1.0052
# 	 	 Training Acc: 0.7177, Validation Acc: 0.6903
# 	 	 Last Char Training Acc: 0.6875, Last Char Validation Acc: 0.6750
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1240000, time elapsed: 9016.11 seconds
# 	 	 Training Loss: 0.9103, Validation Loss: 1.0010
# 	 	 Training Acc: 0.7122, Validation Acc: 0.6916
# 	 	 Last Char Training Acc: 0.6250, Last Char Validation Acc: 0.7188
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1260000, time elapsed: 9157.58 seconds
# 	 	 Training Loss: 0.9328, Validation Loss: 1.0093
# 	 	 Training Acc: 0.7041, Validation Acc: 0.6941
# 	 	 Last Char Training Acc: 0.5312, Last Char Validation Acc: 0.6562
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1280000, time elapsed: 9302.36 seconds
# 	 	 Training Loss: 0.8930, Validation Loss: 0.9836
# 	 	 Training Acc: 0.7170, Validation Acc: 0.6984
# 	 	 Last Char Training Acc: 0.6875, Last Char Validation Acc: 0.6938
# --------------------------------------------------
# [save_to_drive] Successfully saved training_results.log to /content/drive/MyDrive/final_model_results
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1300000, time elapsed: 9441.18 seconds
# 	 	 Training Loss: 0.9156, Validation Loss: 1.0099
# 	 	 Training Acc: 0.7097, Validation Acc: 0.6906
# 	 	 Last Char Training Acc: 0.8438, Last Char Validation Acc: 0.7375
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1320000, time elapsed: 9582.45 seconds
# 	 	 Training Loss: 0.9090, Validation Loss: 1.0059
# 	 	 Training Acc: 0.7167, Validation Acc: 0.6900
# 	 	 Last Char Training Acc: 0.6562, Last Char Validation Acc: 0.7188
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1340000, time elapsed: 9723.65 seconds
# 	 	 Training Loss: 0.9104, Validation Loss: 1.0102
# 	 	 Training Acc: 0.7094, Validation Acc: 0.6907
# 	 	 Last Char Training Acc: 0.9375, Last Char Validation Acc: 0.7688
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1360000, time elapsed: 9866.07 seconds
# 	 	 Training Loss: 0.8964, Validation Loss: 1.0208
# 	 	 Training Acc: 0.7151, Validation Acc: 0.6884
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.7437
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1380000, time elapsed: 10007.06 seconds
# 	 	 Training Loss: 0.9091, Validation Loss: 0.9973
# 	 	 Training Acc: 0.7147, Validation Acc: 0.6930
# 	 	 Last Char Training Acc: 0.7188, Last Char Validation Acc: 0.7312
# --------------------------------------------------
# [save_to_drive] Successfully saved training_results.log to /content/drive/MyDrive/final_model_results
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1400000, time elapsed: 10150.08 seconds
# 	 	 Training Loss: 0.8812, Validation Loss: 0.9883
# 	 	 Training Acc: 0.7180, Validation Acc: 0.6958
# 	 	 Last Char Training Acc: 0.7188, Last Char Validation Acc: 0.6938
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1420000, time elapsed: 10293.96 seconds
# 	 	 Training Loss: 0.8876, Validation Loss: 0.9932
# 	 	 Training Acc: 0.7231, Validation Acc: 0.6935
# 	 	 Last Char Training Acc: 0.6875, Last Char Validation Acc: 0.6812
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1440000, time elapsed: 10441.99 seconds
# 	 	 Training Loss: 0.8759, Validation Loss: 0.9833
# 	 	 Training Acc: 0.7201, Validation Acc: 0.6969
# 	 	 Last Char Training Acc: 0.6875, Last Char Validation Acc: 0.6875
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1460000, time elapsed: 10583.62 seconds
# 	 	 Training Loss: 0.8892, Validation Loss: 1.0121
# 	 	 Training Acc: 0.7217, Validation Acc: 0.6881
# 	 	 Last Char Training Acc: 0.8438, Last Char Validation Acc: 0.6875
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1480000, time elapsed: 10726.05 seconds
# 	 	 Training Loss: 0.8842, Validation Loss: 1.0112
# 	 	 Training Acc: 0.7235, Validation Acc: 0.6893
# 	 	 Last Char Training Acc: 0.8438, Last Char Validation Acc: 0.7250
# --------------------------------------------------
# [save_to_drive] Successfully saved training_results.log to /content/drive/MyDrive/final_model_results
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1500000, time elapsed: 10868.70 seconds
# 	 	 Training Loss: 0.9414, Validation Loss: 1.0020
# 	 	 Training Acc: 0.7031, Validation Acc: 0.6932
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.7250
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1520000, time elapsed: 11011.63 seconds
# 	 	 Training Loss: 0.9621, Validation Loss: 1.0114
# 	 	 Training Acc: 0.6973, Validation Acc: 0.6925
# 	 	 Last Char Training Acc: 0.6562, Last Char Validation Acc: 0.6625
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1540000, time elapsed: 11152.85 seconds
# 	 	 Training Loss: 0.9305, Validation Loss: 0.9884
# 	 	 Training Acc: 0.7091, Validation Acc: 0.6995
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.7125
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1560000, time elapsed: 11295.13 seconds
# 	 	 Training Loss: 0.8647, Validation Loss: 0.9893
# 	 	 Training Acc: 0.7268, Validation Acc: 0.6985
# 	 	 Last Char Training Acc: 0.7188, Last Char Validation Acc: 0.6687
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1580000, time elapsed: 11438.61 seconds
# 	 	 Training Loss: 0.8770, Validation Loss: 0.9831
# 	 	 Training Acc: 0.7211, Validation Acc: 0.6991
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.6812
# --------------------------------------------------
# [save_to_drive] Successfully saved training_results.log to /content/drive/MyDrive/final_model_results
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1600000, time elapsed: 11580.79 seconds
# 	 	 Training Loss: 0.8891, Validation Loss: 0.9962
# 	 	 Training Acc: 0.7246, Validation Acc: 0.6963
# 	 	 Last Char Training Acc: 0.6875, Last Char Validation Acc: 0.7188
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1620000, time elapsed: 11724.21 seconds
# 	 	 Training Loss: 0.9133, Validation Loss: 0.9814
# 	 	 Training Acc: 0.7120, Validation Acc: 0.7002
# 	 	 Last Char Training Acc: 0.6562, Last Char Validation Acc: 0.7000
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1640000, time elapsed: 11867.76 seconds
# 	 	 Training Loss: 0.9398, Validation Loss: 1.0131
# 	 	 Training Acc: 0.7048, Validation Acc: 0.6910
# 	 	 Last Char Training Acc: 0.6562, Last Char Validation Acc: 0.7000
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1660000, time elapsed: 12011.21 seconds
# 	 	 Training Loss: 0.8949, Validation Loss: 1.0010
# 	 	 Training Acc: 0.7134, Validation Acc: 0.6960
# 	 	 Last Char Training Acc: 0.8438, Last Char Validation Acc: 0.7188
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1680000, time elapsed: 12154.31 seconds
# 	 	 Training Loss: 0.8769, Validation Loss: 0.9658
# 	 	 Training Acc: 0.7238, Validation Acc: 0.7018
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.7688
# --------------------------------------------------
# [save_to_drive] Successfully saved training_results.log to /content/drive/MyDrive/final_model_results
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1700000, time elapsed: 12306.69 seconds
# 	 	 Training Loss: 0.8443, Validation Loss: 0.9945
# 	 	 Training Acc: 0.7329, Validation Acc: 0.6947
# 	 	 Last Char Training Acc: 0.7812, Last Char Validation Acc: 0.7125
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1720000, time elapsed: 12451.46 seconds
# 	 	 Training Loss: 0.9279, Validation Loss: 0.9987
# 	 	 Training Acc: 0.7100, Validation Acc: 0.6961
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.7563
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1740000, time elapsed: 12594.37 seconds
# 	 	 Training Loss: 0.8842, Validation Loss: 1.0146
# 	 	 Training Acc: 0.7261, Validation Acc: 0.6896
# 	 	 Last Char Training Acc: 0.8125, Last Char Validation Acc: 0.7312
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1760000, time elapsed: 12738.54 seconds
# 	 	 Training Loss: 0.9000, Validation Loss: 0.9957
# 	 	 Training Acc: 0.7220, Validation Acc: 0.6947
# 	 	 Last Char Training Acc: 0.6250, Last Char Validation Acc: 0.6938
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1780000, time elapsed: 12881.14 seconds
# 	 	 Training Loss: 0.9317, Validation Loss: 0.9978
# 	 	 Training Acc: 0.7036, Validation Acc: 0.6955
# 	 	 Last Char Training Acc: 0.6875, Last Char Validation Acc: 0.6875
# --------------------------------------------------
# [save_to_drive] Successfully saved training_results.log to /content/drive/MyDrive/final_model_results
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1800000, time elapsed: 13024.33 seconds
# 	 	 Training Loss: 0.9300, Validation Loss: 1.0014
# 	 	 Training Acc: 0.7091, Validation Acc: 0.6942
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.7188
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1820000, time elapsed: 13165.93 seconds
# 	 	 Training Loss: 0.8667, Validation Loss: 0.9861
# 	 	 Training Acc: 0.7252, Validation Acc: 0.6958
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.6938
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1840000, time elapsed: 13305.29 seconds
# 	 	 Training Loss: 0.8960, Validation Loss: 1.0054
# 	 	 Training Acc: 0.7172, Validation Acc: 0.6935
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.7125
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1860000, time elapsed: 13449.41 seconds
# 	 	 Training Loss: 0.8868, Validation Loss: 1.0059
# 	 	 Training Acc: 0.7172, Validation Acc: 0.6946
# 	 	 Last Char Training Acc: 0.6875, Last Char Validation Acc: 0.6875
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1880000, time elapsed: 13592.41 seconds
# 	 	 Training Loss: 0.9325, Validation Loss: 1.0160
# 	 	 Training Acc: 0.7052, Validation Acc: 0.6927
# 	 	 Last Char Training Acc: 0.8438, Last Char Validation Acc: 0.7000
# --------------------------------------------------
# [save_to_drive] Successfully saved training_results.log to /content/drive/MyDrive/final_model_results
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1900000, time elapsed: 13733.86 seconds
# 	 	 Training Loss: 0.8894, Validation Loss: 0.9890
# 	 	 Training Acc: 0.7195, Validation Acc: 0.6979
# 	 	 Last Char Training Acc: 0.7188, Last Char Validation Acc: 0.7188
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1920000, time elapsed: 13876.38 seconds
# 	 	 Training Loss: 0.9233, Validation Loss: 1.0111
# 	 	 Training Acc: 0.7142, Validation Acc: 0.6927
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.6750
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1940000, time elapsed: 14021.25 seconds
# 	 	 Training Loss: 0.9402, Validation Loss: 0.9948
# 	 	 Training Acc: 0.7051, Validation Acc: 0.6982
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.7437
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1960000, time elapsed: 14161.40 seconds
# 	 	 Training Loss: 0.8683, Validation Loss: 0.9837
# 	 	 Training Acc: 0.7177, Validation Acc: 0.7006
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.7188
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1980000, time elapsed: 14302.87 seconds
# 	 	 Training Loss: 0.8434, Validation Loss: 0.9800
# 	 	 Training Acc: 0.7308, Validation Acc: 0.6996
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.6375
# --------------------------------------------------
# [save_to_drive] Successfully saved training_results.log to /content/drive/MyDrive/final_model_results
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 1999999, time elapsed: 14455.84 seconds
# 	 	 Training Loss: 0.9100, Validation Loss: 1.0150
# 	 	 Training Acc: 0.7140, Validation Acc: 0.6891
# 	 	 Last Char Training Acc: 0.7188, Last Char Validation Acc: 0.7063
# --------------------------------------------------
# Training completed in 14455.85 seconds.

# %% [markdown]
# ## Testing the model on test data
#
# Finally, we test the trained model on the test dataset over a set number of batches (`evaluation_batches`) to evaluate its performance. The test loss, accuracy and accuracy of the last character prediction are computed and reported.

# %%
# No. of batches to use for evaluation
evaluation_batches = 100

total_test_loss, total_test_acc, total_last_char_test_acc = tr_utils.evaluate_on_test_set(
    rng = rng,
    model = model_obj,
    params = params,
    constants = constants,
    test_data = test_data,
    batch_size = batch_size,
    seq_len = seq_len,
    loss_type = loss_type,
    aux_loss = use_auxiliary_loss,
    aux_weight = aux_weight,
    label_smoothing = label_smoothing,
    n_batches = evaluation_batches
)

for i in range(evaluation_batches):

    # Update test log
    su_utils.update_test_log(
        log_path = "./test_results.log",
        test_loss = total_test_loss[i],
        test_acc = total_test_acc[i],
        last_char_test_acc = total_last_char_test_acc[i]
    )

# Save test log to google drive
su_utils.save_to_drive(
    drive_backup_dir=DRIVE_BACKUP_DIR,
    file_name="test_results.log"
)
# Out:
# [evaluate_on_test_set] Metrics are averaged over 100 batches.
# Mean Test Loss: 1.0097, Mean Test Accuracy: 0.6928, Mean Last Character Test Accuracy: 0.6963
# Min Test Acc: 0.6632, Max Test Accuracy: 0.7240, Max Last Character Test Accuracy: 0.8750
# Max Test Acc: 0.7240, Min Test Accuracy: 0.6632, Min Last Character Test Accuracy: 0.5312
# S.D of Test Acc: 0.0108, S.D of Test Accuracy: 0.0108, S.D of Last Character Test Accuracy: 0.0776
#
# [save_to_drive] Successfully saved test_results.log to /content/drive/MyDrive/final_model_results

# %% [markdown]
# ## Plot the loss and accuracy curves
#
# After training, we plot the training and validation loss curves to visualize the model's learning progress over time. This plot is saved to the specified output directory, and will be useful to observe trends such as overfitting or underfitting.
#
# We also plot the training and validation accuracy curves to visualize the model's performance over time. This plot is saved to the specified output directory, and will help in assessing how well the model is learning to predict the next character in the sequence. We add in the mean test accuracy as well for comparison.

# %%
name_of_plot = "loss_curve"

# Plot training and validation loss curves
plt.plot(train_step_history, train_loss_history, "-",label='Training Loss', color='blue')
plt.plot(val_step_history, val_loss_history, "-", label='Validation Loss', lw = 2, color='red')
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.legend(loc = "upper right")
plt.title("Training and Validation Loss over Iterations")
plt.legend()
plt.savefig(f"./{name_of_plot}.png")
plt.show()

# Save plots to Drive
su_utils.save_to_drive(
    drive_backup_dir=DRIVE_BACKUP_DIR,
    file_name=f"{name_of_plot}.png"
)
# Out:
# [save_to_drive] Successfully saved loss_curve.png to /content/drive/MyDrive/final_model_results

# %%
# Save plots to Drive
name_of_plot = "accuracy_curve"

# Plot training and validation loss curves
plt.plot(train_step_history, train_acc_history, "-",label='Training Accuracy', color='blue')
plt.plot(val_step_history, val_acc_history, "-", label='Validation Accuracy', lw = 2, color='red')
plt.scatter([iter_max], np.mean(total_test_acc), label='Test Accuracy', color='green', s = 50)
plt.xlabel("Iteration")
plt.ylabel("Accuracy")
plt.legend(loc = "upper right")
plt.title("Training and Validation Accuracy over Iterations")
plt.legend()
plt.savefig(f"./{name_of_plot}.png")
plt.show()

# Save plots to Drive
su_utils.save_to_drive(
    drive_backup_dir=DRIVE_BACKUP_DIR,
    file_name=f"{name_of_plot}.png"
)
# Out:
# [save_to_drive] Successfully saved accuracy_curve.png to /content/drive/MyDrive/final_model_results

# %%
name_of_plot = "last_char_accuracy_curve"

# Plot training and validation loss curves
plt.plot(train_step_history, last_char_train_acc_history, "-",label='Training Accuracy for last char', color='blue')
plt.plot(val_step_history, last_char_val_acc_history, "-", label='Validation Accuracy for last char', lw = 2, color='red')
plt.scatter([iter_max], np.mean(total_last_char_test_acc), label='Test Accuracy for last char', color='green', s = 50)
plt.xlabel("Iteration")
plt.ylabel("Accuracy")
plt.legend(loc = "upper right")
plt.title("Training and Validation Accuracy for Last Character over Iterations")
plt.legend()
plt.savefig(f"./{name_of_plot}.png")
plt.show()

# Save plots to Drive
su_utils.save_to_drive(
    drive_backup_dir=DRIVE_BACKUP_DIR,
    file_name=f"{name_of_plot}.png"
)
# Out:
# [save_to_drive] Successfully saved last_char_accuracy_curve.png to /content/drive/MyDrive/final_model_results

# %% [markdown]
# # Testing the model on a given prompt
#
# We finally test the trained model by generating text based on a given prompt. The model successfully generates a sequence of characters that continue from the prompt, and we save the generated text to a file for review.

# %%
# Test the model on a given prompt
prompt = "the meaning of life is"
encoded_prompt = tr_utils.encode(prompt, chars_to_int)
context = encoded_prompt[None, :]

generate_len = 1000
rng = jax.random.PRNGKey(seed)

output_indices = tr_utils.generate_tokens(
    model=model_obj,
    params=params,
    constants=constants,
    rng=rng,
    context=context,
    length=generate_len,
    block_size=seq_len,
    temperature=0.8,
    sample=True,
    pad_id=None,
    deterministic=True
)

output_indices = np.array(output_indices)  # Convert from JAX array to NumPy array
generated_text = tr_utils.decode(output_indices, int_to_chars)

print("Generated ID Shape:", output_indices.shape)
print("Generated Text:")
print(prompt + generated_text)

generated_text_file = "./generated_text.txt"

with open(generated_text_file, "w") as f:
    f.write(prompt + generated_text)
    print(f"[Sample text generation] Generated text saved to {generated_text_file}.")

# Save generated text to Drive
su_utils.save_to_drive(
    drive_backup_dir=DRIVE_BACKUP_DIR,
    file_name="generated_text.txt"
)
# Out:
# Generated ID Shape: (1, 1000)
# Generated Text:
# the meaning of life is told that the anguish the only way to its headwords actually since it was touched by henry viii offering to its popularity of its large country suburbs the government fell to the public effectively complete liberal political anarchists agreed that its leaders were in such struggle that any political anarchist proposals have been subsequently complied or tried and perceived as military unity he also served on a corporation for religious and personal affairs in the one nine eight zero s capitalism is sometimes credited with a low price and underwater classification there has been an autonomous approval by the european federation the treaty of novgorod was restored a constitutional monarchy and government in its united nations however in the two zero th century one new eu member states believed in the treatment of the united states the national assembly establishes a stake to determine which the provincial and member of the treaty of communist party of italy see north american individual
# [Sample text generation] Generated text saved to ./generated_text.txt.
# [save_to_drive] Successfully saved generated_text.txt to /content/drive/MyDrive/final_model_results
