# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
# Read in all the validation_results.log files from the different experiments
batch16 = pd.read_csv('./batch_size_16/validation_results.log')
batch32 = pd.read_csv('./batch_size_32/validation_results.log')
batch64 = pd.read_csv('./batch_size_64/validation_results.log')
batch128 = pd.read_csv('./batch_size_128/validation_results.log')

# %%
def ema_smooth(x, alpha=0.2):
    smoothed = []
    last = x[0]
    for v in x:
        last = alpha * v + (1 - alpha) * last
        smoothed.append(last)
    return smoothed

# %%
# Plotting all the validation loss curves for comparison
# Use vaLidation step as x-axis and validation loss as y-axis
plt.figure(figsize=(12, 8))

plt.plot(batch16['step'], batch16[' val_loss'], alpha=0.15, color='red')
plt.plot(batch16['step'], ema_smooth(batch16[' val_loss']), label='batch_size: 16', color='red')

plt.plot(batch32['step'], batch32[' val_loss'], alpha=0.15, color='orange')
plt.plot(batch32['step'], ema_smooth(batch32[' val_loss']), label='batch_size: 32', color='orange')

plt.plot(batch64['step'], batch64[' val_loss'], alpha=0.15, color='green')
plt.plot(batch64['step'], ema_smooth(batch64[' val_loss']), label='batch_size: 64', color='green')

plt.plot(batch128['step'], batch128[' val_loss'], alpha=0.15, color='blue')
plt.plot(batch128['step'], ema_smooth(batch128[' val_loss']), label='batch_size: 128', color='blue')

plt.yscale('log')
plt.xlabel('Validation Step')
plt.ylabel('Validation Loss')
plt.title('Batch Size')
plt.legend()
plt.grid()
plt.savefig('batch_size.jpg')
plt.show()

# %%
# Plotting all the validation accuracy curves for comparison
plt.figure(figsize=(12, 8))
plt.plot(batch16['step'], batch16[' val_acc'], alpha=0.15, color='red')
plt.plot(batch16['step'], ema_smooth(batch16[' val_acc']), label='batch_size: 16', color='red')

plt.plot(batch32['step'], batch32[' val_acc'], alpha=0.15, color='orange')
plt.plot(batch32['step'], ema_smooth(batch32[' val_acc']), label='batch_size: 32', color='orange')

plt.plot(batch64['step'], batch64[' val_acc'], alpha=0.15, color='green')
plt.plot(batch64['step'], ema_smooth(batch64[' val_acc']), label='batch_size: 64', color='green')

plt.plot(batch128['step'], batch128[' val_acc'], alpha=0.15, color='blue')
plt.plot(batch128['step'], ema_smooth(batch128[' val_acc']), label='batch_size: 128', color='blue')
plt.xlabel('Validation Step')
plt.ylabel('Validation Accuracy')
plt.title('Batch Size')
plt.legend()
plt.grid()
plt.show()

# %%
# Plotting all the validation accuracy at the last character curves for comparison
plt.figure(figsize=(12, 8))
plt.plot(batch16['step'], batch16[' last_char_val_acc'], alpha=0.15, color='red')
plt.plot(batch16['step'], ema_smooth(batch16[' last_char_val_acc']), label='batch_size: 16', color='red')

plt.plot(batch32['step'], batch32[' last_char_val_acc'], alpha=0.15, color='orange')
plt.plot(batch32['step'], ema_smooth(batch32[' last_char_val_acc']), label='batch_size: 32', color='orange')

plt.plot(batch64['step'], batch64[' last_char_val_acc'], alpha=0.15, color='green')
plt.plot(batch64['step'], ema_smooth(batch64[' last_char_val_acc']), label='batch_size: 64', color='green')

plt.plot(batch128['step'], batch128[' last_char_val_acc'], alpha=0.15, color='blue')
plt.plot(batch128['step'], ema_smooth(batch128[' last_char_val_acc']), label='batch_size: 128', color='blue')
plt.xlabel('Validation Step')
plt.ylabel('Validation Accuracy at Last Character')
plt.title('Batch Size')
plt.legend()
plt.grid()
plt.show()
