# %% [markdown]
# # Final Model
#
# After completing all preliminary experiments and hyperparameter tuning, we proceed to train our final character-level language model using the best-found hyperparameters. The following sections detail the training process, evaluation metrics, and visualizations of the model's performance. We ensure to save all relevant results, checkpoints and plots to local storage as well as to Google Drive for future reference and more importantly backup, just in case of any unforeseen runtime disconnections.

# %%
import matplotlib.pyplot as plt
import optax
import sys
import jax
import time
import os
import numpy as np

import setup_utils as su_utils
import training_utils as tr_utils
# Out:
# /usr/local/lib/python3.12/dist-packages/jax/_src/cloud_tpu_init.py:86: UserWarning: Transparent hugepages are not enabled. TPU runtime startup and shutdown time should be significantly improved on TPU v5e and newer. If not already set, you may need to enable transparent hugepages in your VM image (sudo sh -c "echo always > /sys/kernel/mm/transparent_hugepage/enabled")
#   warnings.warn(

# %%
from google.colab import drive
drive.mount('/content/drive')

# Set up a backup drive and download directory
DRIVE_BACKUP_DIR = "/content/drive/MyDrive/final_model_results"
os.makedirs(DRIVE_BACKUP_DIR, exist_ok=True)
# Out:
# Mounted at /content/drive

# %% [markdown]
# # Load the Experiment Setup

# %% [markdown]
# ## Set the relevant directory paths & log files
#
# Here, we set the necessary directories and output paths for saving model checkpoints and log results.

# %%
# Input name of train & test files
train_file = "./text8_train.txt"
test_file = "./text8_test.txt"

# Input name of config and log files
config_file = "./config.json"
training_log_file = "./training_results.log"
validation_log_file = "./validation_results.log"
test_log_file = "./test_results.log"
checkpoint_file = "./checkpoint.pkl"

# %%
# Set up directories and log files
su_utils.setup(training_log_file, validation_log_file, test_log_file)
# Out:
# [initialize_training_log] Initialized training log file at ./training_results.log
# [initialize_validation_log] Initialized validation log file at ./validation_results.log
# [initialize_test_log] Initialized test log file at ./test_results.log

# %% [markdown]
# ## Load the experiment configurations
#
# Prior to running this notebook, the experiment configurations will be set in a 'config.json' file, which will be loaded to set the model hyperparameters and training settings.

# %%
name, description, seed, model, training, throughput = su_utils.load_config("./config.json")

print(f"We will be {description}")
# Out:
# [load_config] Loaded configuration from ./config.json
# We will be Training the final character-level LLM with chosen architecture and hyperparameters.

# %%
# Set up Model Configurations
vocab_size, d_model, n_heads = model['vocab_size'], model['d_model'], model['n_heads']
n_layers, mlp_ratio, seq_len = model['n_layers'], model['mlp_ratio'], model['seq_len']

dropout, pos_encoding, attention_type = model['dropout'], model['pos_encoding'], model['attention_type']
use_auxiliary_loss, aux_heads, aux_weight = model['use_auxiliary_loss'], model['aux_heads'], model['aux_weight']
loss_type, mixed_precision = model['loss_type'], model['mixed_precision']

print(
    f"Model configurations set: \n"
    f"d_model={d_model}, n_heads={n_heads}, n_layers={n_layers}, seq_len={seq_len}\n"
    f"n_layers={n_layers}, mlp_ratio={mlp_ratio}, dropout={dropout}\n"
)

# Set up Training Configurations
val_fraction, batch_size = training['val_fraction'], training['batch_size']
learning_rate, weight_decay, lr_schedule = training['learning_rate'], training['weight_decay'], training['lr_schedule']
optimizer_type, warmup_ratio, label_smoothing, grad_clip = training['optimizer'], training['warmup_ratio'], float(training['label_smoothing']), training['grad_clip']

print(
    f"Training configurations set: \n"
    f"batch_size={batch_size}, learning_rate={learning_rate}, weight_decay={weight_decay}\n"
    f"optimizer={optimizer_type}, lr_schedule={lr_schedule}, warmup_ratio={warmup_ratio}\n"
)

# Set up Throughput Configurations
max_test_iters, max_test_time = throughput['max_test_iters'], throughput['max_test_time_in_seconds']
compute_budget_hours = throughput['compute_budget_hours']

print(
    f"Throughput configurations set: \n"
    f"max_test_iters={max_test_iters}iters, max_test_time={max_test_time}s, compute_budget_hours={compute_budget_hours}H ({compute_budget_hours*3600:.2f}s)\n"
)
# Out:
# Model configurations set:
# d_model=256, n_heads=4, n_layers=6, seq_len=256
# n_layers=6, mlp_ratio=4, dropout=0.0
#
# Training configurations set:
# batch_size=32, learning_rate=0.0009632654721866886, weight_decay=0.05
# optimizer=adamw, lr_schedule=warmup_decay, warmup_ratio=0.1306142633759742
#
# Throughput configurations set:
# max_test_iters=2000iters, max_test_time=60s, compute_budget_hours=4H (14400.00s)

# %% [markdown]
# # Loading the Data
#
# The text8 dataset is used, which has 100M characters of text data from Wikipedia articles. It contains only lowercase letters and spaces, and is already pre-split into 90M characters for training and 10M characters for testing.

# %%
train_text, test_text, chars_to_int, int_to_chars = su_utils.load_dataset(train_file, test_file)
# Out:
# [load_dataset] Loaded training text from ./text8_train.txt. Length: 90,000,000 characters.
#
# [load_dataset] Loaded testing text from ./text8_test.txt. Length: 5,000,000 characters.
#
# [load_dataset] First 100 characters of training text:
#  anarchism originated as a term of abuse first used against early working class radicals including t
#
# [load_dataset] First 100 characters of testing text:
# be ejected and hold it there examine the chamber to ensure it is clear allow the action to go forwar
#
# [load_dataset] Created character mappings. Vocabulary size: 27

# %% [markdown]
# We further split the training data into a training set and a validation set to monitor the model's performance during training, in accordance to the validation fraction specified in our configuration file (10%)

# %%
train_text, val_text = su_utils.split_train_val(train_text, val_fraction=val_fraction)
# Out:
# [split_train_val] Training text length: 89,099,996 characters.
# [split_train_val] Validation text length: 900,004 characters.

# %% [markdown]
# We then encode the text data into integer format for model training. Each unique character is mapped to a unique integer index.

# %%
# Encode the train, val, test texts
train_data = tr_utils.encode(train_text, chars_to_int)
val_data = tr_utils.encode(val_text, chars_to_int)
test_data = tr_utils.encode(test_text, chars_to_int)

# %% [markdown]
# # Model Initialisation

# %% [markdown]
# ## Model Setup
#
# We intialise our model with the following parameters in accordance to our configuration file.
# Based on these parameters, our model has approximately ~4.2M parameters.

# %%
# Define the model params
rng = jax.random.PRNGKey(seed)

model_obj, params, constants = tr_utils.create_train_state(
        rng,
        vocab_size = vocab_size,
        d_model = d_model,
        n_heads = n_heads,
        n_layers = n_layers,
        mlp_ratio = mlp_ratio,
        seq_len = seq_len,
        dropout = dropout,
        aux_loss = use_auxiliary_loss,
        num_aux_heads = aux_heads,
        mixed_precision = mixed_precision,
        attention_type = attention_type,
        pos_encoding = pos_encoding
)
# Out:
# [create_train_state] Model initialized with 4,160,768 parameters.

# %% [markdown]
# We perform a sanity check by running a single forward pass with random input data to ensure the model is functioning as expected.

# %%
# SANITY CHECK: Test the model forward pass
B, T = 2, 8  # Batch size and sequence length
batch = jax.random.randint(key = rng, shape = (B, T), minval = 0, maxval = vocab_size)

variables = {"params": params, "constants": constants}
output = model_obj.apply(variables, batch, deterministic=False, rngs={"dropout": rng})

print("Logits shape:", output["logits"].shape)  # Expected: (B, T, vocab_size)

if output["logits"].shape[0] == B and output["logits"].shape[1] == T and output["logits"].shape[2] == vocab_size:
    print("Sanity check passed: Model forward pass output shape is correct.")
else:
    print("Sanity check failed: Model forward pass output shape is incorrect.")
# Out:
# Logits shape: (2, 8, 27)
# Sanity check passed: Model forward pass output shape is correct.

# %% [markdown]
# ## Determine maximum permissible training steps
#
# Taking into account possible compute limitations, we perform a preliminary calculation to determine the maximum number of training steps we can perform based on the throughput of our model and the total training time available. For this preliminary test, the default maximum training time is 60 seconds, and commpute budget hours is 4 hours.
#
# Based on the throughput calculated from the preliminary test, the estimated maximum no. of training steps we can perform within this compute budget is ~1.2M. To ensure we keep within the budget, we set the maximum training steps to be 1M.

# %%
# Create a dummy optimizer and opt_state for throughput calculation
dummy_optimizer, dummy_opt_state = tr_utils.create_dummy_optimizer(
    learning_rate = learning_rate,
    optimizer_type = optimizer_type,
    weight_decay = weight_decay,
    params = params
)

# Determining how many steps we can run in a reasonable time
_ , max_steps = tr_utils.calculate_throughput(
    max_test_iters = max_test_iters,
    max_test_time = max_test_time,
    model = model_obj,
    params = params,
    opt_state = dummy_opt_state,
    optimizer = dummy_optimizer,
    rng = rng,
    batch_size = batch_size,
    seq_len = seq_len,
    compute_budget = compute_budget_hours,
    train_data = train_data,
    loss_type = loss_type,
    aux_loss = use_auxiliary_loss,
    aux_weight = aux_weight,
    constants = constants,
    label_smoothing = label_smoothing
)
# Out:
# Benchmark completed in 23.81 seconds.
# Total tokens processed: 16384000
# Throughput: 688188.40 tokens/second
# Estimated max steps within compute budget: 1209706.0

# %% [markdown]
# ## Initialise the optimizer
#
# In this section, we set up the optimizer for training our model in accordance to our configuration file.

# %%
iter_max = 1000000 # Set max iterations in accordance to compute budget
# iter_max = int(max_steps * 0.9)  # If we want to use 90% of the computed max steps
print(f"Setting iter_max = {iter_max}.\n")

optimizer, opt_state = tr_utils.initialize_optimizer(
    params=params,
    iter_max=iter_max,
    optimizer_type=optimizer_type,
    lr_schedule=lr_schedule,
    learning_rate=learning_rate,
    weight_decay=weight_decay,
    warmup_ratio=warmup_ratio,
    grad_clip=grad_clip
)
# Out:
# Setting iter_max = 1000000.
#
# [initialize_optimizer] Initialized adamw optimizer configurations:learning_rate_schedule=warmup_decay, learning_rate=0.0009632654721866886, weight_decay=0.05, grad_clip=noneweight_decay applied: yes, grad_clip applied: nowarmup_ratio=0.1306142633759742, total_iterations=1000000

# %% [markdown]
# # Model Training & Evaluation

# %% [markdown]
# ## Training the model
#
# Now, we proceed to train the model over the determined number of training iterations. During training, we monitor the training loss and periodically evaluate the model on the validation set to track its performance. We also make sure to record the time taken for training to ensure it stays within our compute budget.

# %%
log_val_every = max(1, iter_max // 100) # Determine Validation logging frequency
save_checkpoint_every = max(1, iter_max // 20) # Determine Checkpoint saving frequency
upload_to_drive_every = max(1, iter_max // 20) # Determine Drive upload frequency
num_val_batches = 5  # Number of validation batches to average over

# To track training and validation loss, as well as time taken
train_loss_history = []
val_loss_history = []
train_acc_history = []
val_acc_history = []
last_char_train_acc_history = []
last_char_val_acc_history = []
train_step_history = list(range(iter_max))
val_step_history = []

# Load checkpoint if it exists
params, opt_state, constants, start_iter = su_utils.load_checkpoint(
    checkpoint_file,
    params,
    constants,
    opt_state
)
# Out:
# [load_checkpoint] No checkpoint found at ./checkpoint.pkl
# [load_checkpoint] Starting training as per normal.

# %% [markdown]
# We then train the model and log the training and validation losses for analysis. All relevant results, checkpoints and plots are saved periodically to local storage as well as to Google Drive for future reference and backup.

# %%
if start_iter > 0:
        print(f"Resuming training from iteration = {start_iter}.")
else:
        print("Starting training from iteration = 0.")

time_start = time.time()
best_val_loss = float('inf')

for it in range(start_iter, iter_max):

    # get a batch of data
    inputs, targets = tr_utils.get_batch(train_data, batch_size, seq_len)

    # Perform a training step
    rng, sub = jax.random.split(rng)
    new_params, new_opt_state, metrics = tr_utils.train_step(
            model = model_obj,
            params = params,
            constants=constants,
            opt_state = opt_state,
            x = inputs,
            y = targets,
            tx = optimizer,
            rng = sub,
            loss_type = loss_type,
            aux_loss = use_auxiliary_loss,
            aux_weight = aux_weight,
            label_smoothing = label_smoothing
    )

    # Update parameters and optimizer state
    params = new_params
    opt_state = new_opt_state

    # Record training metrics
    acc = metrics['acc']
    loss = metrics['loss']
    last_char_acc = metrics['acc_last']
    train_time = time.time() - time_start

    train_loss_history.append(loss)
    train_acc_history.append(acc)
    last_char_train_acc_history.append(last_char_acc)

    su_utils.update_training_log(
        log_path = "training_results.log",
        step = it,
        train_loss = loss,
        train_time = train_time,
        train_acc = acc,
        last_char_acc = last_char_acc
        )

    # Upload training log to Drive at regular intervals
    if (it % upload_to_drive_every) == 0 or (it == iter_max - 1):
        su_utils.save_to_drive(
            drive_backup_dir=DRIVE_BACKUP_DIR,
            file_name="training_results.log"
        )

    # Perform validation and checkpoint saving at specified intervals
    if (it % log_val_every) == 0 or (it == iter_max - 1): # Print every 1% of iterations

        val_losses = []
        val_accs = []
        val_last_char_accs = []

        for _ in range(num_val_batches):
            # Compute the loss on validation set
            batch_size_val = batch_size
            seq_len_val = seq_len
            val_inputs, val_targets = tr_utils.get_batch(val_data, batch_size_val, seq_len_val)

            val_out = model_obj.apply({"params": params, "constants": constants}, val_inputs, deterministic=True, rngs={"dropout": rng})
            val_logits = val_out["logits"]
            val_aux_logits = val_out.get('aux_logits', None)

            val_loss, val_metrics = tr_utils.loss_and_metrics(
                logits = val_logits,
                targets = val_targets,
                loss_type = loss_type,
                aux_loss = use_auxiliary_loss,
                aux_logits = val_aux_logits,
                aux_weight = aux_weight,
                label_smoothing = label_smoothing
            )

            # Record validation loss and time
            val_acc = val_metrics['acc']
            last_char_acc_val = val_metrics['acc_last']

            # Add validation metrics to lists
            val_losses.append(val_loss)
            val_accs.append(val_acc)
            val_last_char_accs.append(last_char_acc_val)

        # Compute average validation metrics
        val_loss = np.mean(val_losses)
        val_acc = np.mean(val_accs)
        last_char_acc_val = np.mean(val_last_char_accs)

        # Record validation loss and time
        val_loss_history.append(val_loss)
        val_acc_history.append(val_acc)
        last_char_val_acc_history.append(last_char_acc_val)
        time_elapsed = time.time() - time_start
        val_step_history.append(it)

        su_utils.update_validation_log(
            log_path = "validation_results.log",
            step = it,
            val_loss = val_loss,
            val_time = time_elapsed,
            val_acc = val_acc,
            last_char_val_acc = last_char_acc_val
        )

        # Upload validation log to Drive at regular intervals
        su_utils.save_to_drive(
            drive_backup_dir=DRIVE_BACKUP_DIR,
            file_name="validation_results.log"
        )

        # Save checkpoint at regular intervals
        if ((it % save_checkpoint_every) == 0 or (it == iter_max - 1)) and (val_loss - 0.005 < best_val_loss):

            # Save checkpoint in local directory
            su_utils.save_checkpoint(
                checkpoint_path = checkpoint_file,
                params = params,
                constants = constants,
                opt_state = opt_state,
                step = it,
                time_elapsed = time_elapsed
            )

            # Save checkpoint to Drive
            su_utils.save_to_drive(
                drive_backup_dir=DRIVE_BACKUP_DIR,
                file_name=checkpoint_file.split("/")[-1]
            )

            best_val_loss = val_loss

        # Print training and validation metrics
        print(f"Iteration {it}, time elapsed: {time_elapsed:.2f} seconds")
        print(f"\t \t Training Loss: {loss:.4f}, Validation Loss: {val_loss:.4f}")
        print(f"\t \t Training Acc: {acc:.4f}, Validation Acc: {val_acc:.4f}")
        print(f"\t \t Last Char Training Acc: {last_char_acc:.4f}, Last Char Validation Acc: {last_char_acc_val:.4f}")
        print("-" * 50)

print(f"Training completed in {time.time() - time_start:.2f} seconds.")
# Out:
# Starting training from iteration = 0.
# [save_to_drive] Successfully saved training_results.log to /content/drive/MyDrive/final_model_results
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# [save_checkpoint] Saved checkpoint at step 0 to ./checkpoint.pkl
# [save_to_drive] Successfully saved checkpoint.pkl to /content/drive/MyDrive/final_model_results
# Iteration 0, time elapsed: 23.21 seconds
# 	 	 Training Loss: 3.7208, Validation Loss: 3.7092
# 	 	 Training Acc: 0.0674, Validation Acc: 0.0603
# 	 	 Last Char Training Acc: 0.0938, Last Char Validation Acc: 0.0500
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 10000, time elapsed: 91.50 seconds
# 	 	 Training Loss: 1.4066, Validation Loss: 1.3982
# 	 	 Training Acc: 0.5679, Validation Acc: 0.5656
# 	 	 Last Char Training Acc: 0.5625, Last Char Validation Acc: 0.6062
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 20000, time elapsed: 160.46 seconds
# 	 	 Training Loss: 1.2342, Validation Loss: 1.2635
# 	 	 Training Acc: 0.6100, Validation Acc: 0.6026
# 	 	 Last Char Training Acc: 0.8125, Last Char Validation Acc: 0.6562
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 30000, time elapsed: 229.61 seconds
# 	 	 Training Loss: 1.2111, Validation Loss: 1.2266
# 	 	 Training Acc: 0.6158, Validation Acc: 0.6155
# 	 	 Last Char Training Acc: 0.7188, Last Char Validation Acc: 0.6438
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 40000, time elapsed: 297.95 seconds
# 	 	 Training Loss: 1.2193, Validation Loss: 1.1515
# 	 	 Training Acc: 0.6165, Validation Acc: 0.6359
# 	 	 Last Char Training Acc: 0.6562, Last Char Validation Acc: 0.6187
# --------------------------------------------------
# [save_to_drive] Successfully saved training_results.log to /content/drive/MyDrive/final_model_results
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# [save_checkpoint] Saved checkpoint at step 50000 to ./checkpoint.pkl
# [save_to_drive] Successfully saved checkpoint.pkl to /content/drive/MyDrive/final_model_results
# Iteration 50000, time elapsed: 367.48 seconds
# 	 	 Training Loss: 1.0601, Validation Loss: 1.1539
# 	 	 Training Acc: 0.6675, Validation Acc: 0.6396
# 	 	 Last Char Training Acc: 0.7188, Last Char Validation Acc: 0.6687
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 60000, time elapsed: 436.17 seconds
# 	 	 Training Loss: 1.1317, Validation Loss: 1.1041
# 	 	 Training Acc: 0.6481, Validation Acc: 0.6544
# 	 	 Last Char Training Acc: 0.5938, Last Char Validation Acc: 0.6375
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 70000, time elapsed: 506.03 seconds
# 	 	 Training Loss: 1.0811, Validation Loss: 1.1054
# 	 	 Training Acc: 0.6604, Validation Acc: 0.6546
# 	 	 Last Char Training Acc: 0.6250, Last Char Validation Acc: 0.6313
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 80000, time elapsed: 575.50 seconds
# 	 	 Training Loss: 1.0750, Validation Loss: 1.0970
# 	 	 Training Acc: 0.6605, Validation Acc: 0.6572
# 	 	 Last Char Training Acc: 0.5938, Last Char Validation Acc: 0.6812
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 90000, time elapsed: 643.90 seconds
# 	 	 Training Loss: 1.0348, Validation Loss: 1.0707
# 	 	 Training Acc: 0.6779, Validation Acc: 0.6614
# 	 	 Last Char Training Acc: 0.6250, Last Char Validation Acc: 0.7312
# --------------------------------------------------
# [save_to_drive] Successfully saved training_results.log to /content/drive/MyDrive/final_model_results
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# [save_checkpoint] Saved checkpoint at step 100000 to ./checkpoint.pkl
# [save_to_drive] Successfully saved checkpoint.pkl to /content/drive/MyDrive/final_model_results
# Iteration 100000, time elapsed: 714.43 seconds
# 	 	 Training Loss: 1.0306, Validation Loss: 1.0920
# 	 	 Training Acc: 0.6700, Validation Acc: 0.6588
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.6438
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 110000, time elapsed: 783.03 seconds
# 	 	 Training Loss: 1.0329, Validation Loss: 1.0282
# 	 	 Training Acc: 0.6777, Validation Acc: 0.6746
# 	 	 Last Char Training Acc: 0.8125, Last Char Validation Acc: 0.7000
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 120000, time elapsed: 853.21 seconds
# 	 	 Training Loss: 0.9886, Validation Loss: 1.0793
# 	 	 Training Acc: 0.6906, Validation Acc: 0.6632
# 	 	 Last Char Training Acc: 0.7188, Last Char Validation Acc: 0.6687
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 130000, time elapsed: 921.80 seconds
# 	 	 Training Loss: 1.0450, Validation Loss: 1.0490
# 	 	 Training Acc: 0.6727, Validation Acc: 0.6695
# 	 	 Last Char Training Acc: 0.8125, Last Char Validation Acc: 0.6938
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 140000, time elapsed: 991.83 seconds
# 	 	 Training Loss: 1.0347, Validation Loss: 1.0884
# 	 	 Training Acc: 0.6677, Validation Acc: 0.6606
# 	 	 Last Char Training Acc: 0.6562, Last Char Validation Acc: 0.6750
# --------------------------------------------------
# [save_to_drive] Successfully saved training_results.log to /content/drive/MyDrive/final_model_results
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# [save_checkpoint] Saved checkpoint at step 150000 to ./checkpoint.pkl
# [save_to_drive] Successfully saved checkpoint.pkl to /content/drive/MyDrive/final_model_results
# Iteration 150000, time elapsed: 1060.90 seconds
# 	 	 Training Loss: 1.0248, Validation Loss: 1.0443
# 	 	 Training Acc: 0.6892, Validation Acc: 0.6719
# 	 	 Last Char Training Acc: 0.7188, Last Char Validation Acc: 0.6812
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 160000, time elapsed: 1131.39 seconds
# 	 	 Training Loss: 1.0104, Validation Loss: 1.0456
# 	 	 Training Acc: 0.6815, Validation Acc: 0.6721
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.7437
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 170000, time elapsed: 1200.78 seconds
# 	 	 Training Loss: 1.0213, Validation Loss: 1.0399
# 	 	 Training Acc: 0.6816, Validation Acc: 0.6756
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.7000
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 180000, time elapsed: 1271.86 seconds
# 	 	 Training Loss: 0.9857, Validation Loss: 1.0721
# 	 	 Training Acc: 0.6879, Validation Acc: 0.6637
# 	 	 Last Char Training Acc: 0.6875, Last Char Validation Acc: 0.6500
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 190000, time elapsed: 1342.36 seconds
# 	 	 Training Loss: 0.9894, Validation Loss: 1.0821
# 	 	 Training Acc: 0.6838, Validation Acc: 0.6643
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.7188
# --------------------------------------------------
# [save_to_drive] Successfully saved training_results.log to /content/drive/MyDrive/final_model_results
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 200000, time elapsed: 1411.27 seconds
# 	 	 Training Loss: 1.0874, Validation Loss: 1.0574
# 	 	 Training Acc: 0.6492, Validation Acc: 0.6729
# 	 	 Last Char Training Acc: 0.5312, Last Char Validation Acc: 0.7375
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 210000, time elapsed: 1482.43 seconds
# 	 	 Training Loss: 1.0012, Validation Loss: 1.0521
# 	 	 Training Acc: 0.6888, Validation Acc: 0.6717
# 	 	 Last Char Training Acc: 0.7188, Last Char Validation Acc: 0.7375
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 220000, time elapsed: 1552.60 seconds
# 	 	 Training Loss: 1.0468, Validation Loss: 1.0445
# 	 	 Training Acc: 0.6731, Validation Acc: 0.6739
# 	 	 Last Char Training Acc: 0.5625, Last Char Validation Acc: 0.7500
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 230000, time elapsed: 1621.79 seconds
# 	 	 Training Loss: 1.0560, Validation Loss: 1.0260
# 	 	 Training Acc: 0.6696, Validation Acc: 0.6783
# 	 	 Last Char Training Acc: 0.5625, Last Char Validation Acc: 0.6750
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 240000, time elapsed: 1691.47 seconds
# 	 	 Training Loss: 1.0112, Validation Loss: 1.0542
# 	 	 Training Acc: 0.6786, Validation Acc: 0.6705
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.6875
# --------------------------------------------------
# [save_to_drive] Successfully saved training_results.log to /content/drive/MyDrive/final_model_results
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 250000, time elapsed: 1762.52 seconds
# 	 	 Training Loss: 0.9844, Validation Loss: 1.0656
# 	 	 Training Acc: 0.6875, Validation Acc: 0.6659
# 	 	 Last Char Training Acc: 0.7188, Last Char Validation Acc: 0.6250
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 260000, time elapsed: 1833.03 seconds
# 	 	 Training Loss: 1.0215, Validation Loss: 1.0451
# 	 	 Training Acc: 0.6821, Validation Acc: 0.6765
# 	 	 Last Char Training Acc: 0.6250, Last Char Validation Acc: 0.6938
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 270000, time elapsed: 1903.45 seconds
# 	 	 Training Loss: 1.0085, Validation Loss: 1.0192
# 	 	 Training Acc: 0.6838, Validation Acc: 0.6818
# 	 	 Last Char Training Acc: 0.7188, Last Char Validation Acc: 0.6750
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 280000, time elapsed: 1972.79 seconds
# 	 	 Training Loss: 0.9698, Validation Loss: 1.0530
# 	 	 Training Acc: 0.6921, Validation Acc: 0.6729
# 	 	 Last Char Training Acc: 0.5938, Last Char Validation Acc: 0.6438
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 290000, time elapsed: 2043.53 seconds
# 	 	 Training Loss: 0.9929, Validation Loss: 1.0186
# 	 	 Training Acc: 0.6870, Validation Acc: 0.6778
# 	 	 Last Char Training Acc: 0.7812, Last Char Validation Acc: 0.6500
# --------------------------------------------------
# [save_to_drive] Successfully saved training_results.log to /content/drive/MyDrive/final_model_results
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# [save_checkpoint] Saved checkpoint at step 300000 to ./checkpoint.pkl
# [save_to_drive] Successfully saved checkpoint.pkl to /content/drive/MyDrive/final_model_results
# Iteration 300000, time elapsed: 2116.14 seconds
# 	 	 Training Loss: 0.9830, Validation Loss: 1.0449
# 	 	 Training Acc: 0.6901, Validation Acc: 0.6733
# 	 	 Last Char Training Acc: 0.7812, Last Char Validation Acc: 0.6938
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 310000, time elapsed: 2186.70 seconds
# 	 	 Training Loss: 0.9529, Validation Loss: 1.0563
# 	 	 Training Acc: 0.7025, Validation Acc: 0.6709
# 	 	 Last Char Training Acc: 0.6875, Last Char Validation Acc: 0.7063
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 320000, time elapsed: 2257.01 seconds
# 	 	 Training Loss: 1.0396, Validation Loss: 1.0226
# 	 	 Training Acc: 0.6770, Validation Acc: 0.6818
# 	 	 Last Char Training Acc: 0.8125, Last Char Validation Acc: 0.7188
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 330000, time elapsed: 2326.69 seconds
# 	 	 Training Loss: 1.0005, Validation Loss: 1.0042
# 	 	 Training Acc: 0.6825, Validation Acc: 0.6848
# 	 	 Last Char Training Acc: 0.5938, Last Char Validation Acc: 0.6750
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 340000, time elapsed: 2396.39 seconds
# 	 	 Training Loss: 0.9807, Validation Loss: 1.0336
# 	 	 Training Acc: 0.6919, Validation Acc: 0.6763
# 	 	 Last Char Training Acc: 0.7812, Last Char Validation Acc: 0.6812
# --------------------------------------------------
# [save_to_drive] Successfully saved training_results.log to /content/drive/MyDrive/final_model_results
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# [save_checkpoint] Saved checkpoint at step 350000 to ./checkpoint.pkl
# [save_to_drive] Successfully saved checkpoint.pkl to /content/drive/MyDrive/final_model_results
# Iteration 350000, time elapsed: 2466.21 seconds
# 	 	 Training Loss: 0.9654, Validation Loss: 1.0036
# 	 	 Training Acc: 0.6996, Validation Acc: 0.6855
# 	 	 Last Char Training Acc: 0.6875, Last Char Validation Acc: 0.6687
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 360000, time elapsed: 2538.19 seconds
# 	 	 Training Loss: 1.0136, Validation Loss: 1.0125
# 	 	 Training Acc: 0.6738, Validation Acc: 0.6825
# 	 	 Last Char Training Acc: 0.6875, Last Char Validation Acc: 0.6938
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 370000, time elapsed: 2607.51 seconds
# 	 	 Training Loss: 1.0488, Validation Loss: 1.0587
# 	 	 Training Acc: 0.6694, Validation Acc: 0.6691
# 	 	 Last Char Training Acc: 0.5938, Last Char Validation Acc: 0.7625
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 380000, time elapsed: 2677.19 seconds
# 	 	 Training Loss: 0.9359, Validation Loss: 1.0179
# 	 	 Training Acc: 0.7065, Validation Acc: 0.6807
# 	 	 Last Char Training Acc: 0.6875, Last Char Validation Acc: 0.7125
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 390000, time elapsed: 2747.43 seconds
# 	 	 Training Loss: 0.9668, Validation Loss: 1.0247
# 	 	 Training Acc: 0.6993, Validation Acc: 0.6794
# 	 	 Last Char Training Acc: 0.6875, Last Char Validation Acc: 0.6625
# --------------------------------------------------
# [save_to_drive] Successfully saved training_results.log to /content/drive/MyDrive/final_model_results
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# [save_checkpoint] Saved checkpoint at step 400000 to ./checkpoint.pkl
# [save_to_drive] Successfully saved checkpoint.pkl to /content/drive/MyDrive/final_model_results
# Iteration 400000, time elapsed: 2817.92 seconds
# 	 	 Training Loss: 0.9689, Validation Loss: 0.9967
# 	 	 Training Acc: 0.6969, Validation Acc: 0.6871
# 	 	 Last Char Training Acc: 0.7812, Last Char Validation Acc: 0.6875
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 410000, time elapsed: 2888.06 seconds
# 	 	 Training Loss: 1.0429, Validation Loss: 1.0197
# 	 	 Training Acc: 0.6766, Validation Acc: 0.6816
# 	 	 Last Char Training Acc: 0.6875, Last Char Validation Acc: 0.7188
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 420000, time elapsed: 2957.74 seconds
# 	 	 Training Loss: 1.0375, Validation Loss: 1.0338
# 	 	 Training Acc: 0.6736, Validation Acc: 0.6751
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.7000
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 430000, time elapsed: 3030.11 seconds
# 	 	 Training Loss: 1.0507, Validation Loss: 1.0163
# 	 	 Training Acc: 0.6766, Validation Acc: 0.6794
# 	 	 Last Char Training Acc: 0.6562, Last Char Validation Acc: 0.6500
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 440000, time elapsed: 3099.86 seconds
# 	 	 Training Loss: 1.0625, Validation Loss: 1.0067
# 	 	 Training Acc: 0.6660, Validation Acc: 0.6841
# 	 	 Last Char Training Acc: 0.6562, Last Char Validation Acc: 0.6625
# --------------------------------------------------
# [save_to_drive] Successfully saved training_results.log to /content/drive/MyDrive/final_model_results
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 450000, time elapsed: 3169.97 seconds
# 	 	 Training Loss: 0.9979, Validation Loss: 1.0129
# 	 	 Training Acc: 0.6870, Validation Acc: 0.6835
# 	 	 Last Char Training Acc: 0.7812, Last Char Validation Acc: 0.7312
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 460000, time elapsed: 3240.67 seconds
# 	 	 Training Loss: 0.9585, Validation Loss: 1.0186
# 	 	 Training Acc: 0.6981, Validation Acc: 0.6803
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.7312
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 470000, time elapsed: 3309.69 seconds
# 	 	 Training Loss: 0.9433, Validation Loss: 1.0053
# 	 	 Training Acc: 0.7057, Validation Acc: 0.6828
# 	 	 Last Char Training Acc: 0.6875, Last Char Validation Acc: 0.7250
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 480000, time elapsed: 3379.97 seconds
# 	 	 Training Loss: 0.9739, Validation Loss: 1.0055
# 	 	 Training Acc: 0.6924, Validation Acc: 0.6861
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.7188
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 490000, time elapsed: 3450.01 seconds
# 	 	 Training Loss: 0.9602, Validation Loss: 1.0280
# 	 	 Training Acc: 0.6975, Validation Acc: 0.6807
# 	 	 Last Char Training Acc: 0.6875, Last Char Validation Acc: 0.7188
# --------------------------------------------------
# [save_to_drive] Successfully saved training_results.log to /content/drive/MyDrive/final_model_results
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# [save_checkpoint] Saved checkpoint at step 500000 to ./checkpoint.pkl
# [save_to_drive] Successfully saved checkpoint.pkl to /content/drive/MyDrive/final_model_results
# Iteration 500000, time elapsed: 3520.31 seconds
# 	 	 Training Loss: 1.0069, Validation Loss: 0.9992
# 	 	 Training Acc: 0.6792, Validation Acc: 0.6886
# 	 	 Last Char Training Acc: 0.6875, Last Char Validation Acc: 0.7000
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 510000, time elapsed: 3593.09 seconds
# 	 	 Training Loss: 1.0037, Validation Loss: 1.0160
# 	 	 Training Acc: 0.6866, Validation Acc: 0.6821
# 	 	 Last Char Training Acc: 0.6875, Last Char Validation Acc: 0.6625
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 520000, time elapsed: 3664.29 seconds
# 	 	 Training Loss: 0.9047, Validation Loss: 1.0156
# 	 	 Training Acc: 0.7196, Validation Acc: 0.6819
# 	 	 Last Char Training Acc: 0.6562, Last Char Validation Acc: 0.6438
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 530000, time elapsed: 3734.16 seconds
# 	 	 Training Loss: 0.9823, Validation Loss: 1.0126
# 	 	 Training Acc: 0.6918, Validation Acc: 0.6823
# 	 	 Last Char Training Acc: 0.7812, Last Char Validation Acc: 0.6812
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 540000, time elapsed: 3804.27 seconds
# 	 	 Training Loss: 0.9819, Validation Loss: 1.0229
# 	 	 Training Acc: 0.6876, Validation Acc: 0.6782
# 	 	 Last Char Training Acc: 0.7188, Last Char Validation Acc: 0.6938
# --------------------------------------------------
# [save_to_drive] Successfully saved training_results.log to /content/drive/MyDrive/final_model_results
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# [save_checkpoint] Saved checkpoint at step 550000 to ./checkpoint.pkl
# [save_to_drive] Successfully saved checkpoint.pkl to /content/drive/MyDrive/final_model_results
# Iteration 550000, time elapsed: 3875.77 seconds
# 	 	 Training Loss: 0.9806, Validation Loss: 0.9912
# 	 	 Training Acc: 0.6893, Validation Acc: 0.6888
# 	 	 Last Char Training Acc: 0.8438, Last Char Validation Acc: 0.7000
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 560000, time elapsed: 3945.30 seconds
# 	 	 Training Loss: 0.9215, Validation Loss: 0.9999
# 	 	 Training Acc: 0.7101, Validation Acc: 0.6844
# 	 	 Last Char Training Acc: 0.5312, Last Char Validation Acc: 0.7188
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 570000, time elapsed: 4015.77 seconds
# 	 	 Training Loss: 0.9991, Validation Loss: 1.0202
# 	 	 Training Acc: 0.6892, Validation Acc: 0.6836
# 	 	 Last Char Training Acc: 0.8438, Last Char Validation Acc: 0.6812
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 580000, time elapsed: 4085.30 seconds
# 	 	 Training Loss: 0.9443, Validation Loss: 0.9912
# 	 	 Training Acc: 0.7019, Validation Acc: 0.6896
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.6625
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 590000, time elapsed: 4155.10 seconds
# 	 	 Training Loss: 0.9944, Validation Loss: 0.9682
# 	 	 Training Acc: 0.6898, Validation Acc: 0.6940
# 	 	 Last Char Training Acc: 0.8125, Last Char Validation Acc: 0.7375
# --------------------------------------------------
# [save_to_drive] Successfully saved training_results.log to /content/drive/MyDrive/final_model_results
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 600000, time elapsed: 4225.69 seconds
# 	 	 Training Loss: 0.9440, Validation Loss: 1.0161
# 	 	 Training Acc: 0.7052, Validation Acc: 0.6814
# 	 	 Last Char Training Acc: 0.8125, Last Char Validation Acc: 0.6625
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 610000, time elapsed: 4299.11 seconds
# 	 	 Training Loss: 0.9891, Validation Loss: 1.0146
# 	 	 Training Acc: 0.6963, Validation Acc: 0.6833
# 	 	 Last Char Training Acc: 0.6875, Last Char Validation Acc: 0.6938
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 620000, time elapsed: 4369.01 seconds
# 	 	 Training Loss: 0.9904, Validation Loss: 1.0032
# 	 	 Training Acc: 0.6873, Validation Acc: 0.6869
# 	 	 Last Char Training Acc: 0.6562, Last Char Validation Acc: 0.6438
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 630000, time elapsed: 4439.31 seconds
# 	 	 Training Loss: 0.9370, Validation Loss: 1.0219
# 	 	 Training Acc: 0.7017, Validation Acc: 0.6817
# 	 	 Last Char Training Acc: 0.8125, Last Char Validation Acc: 0.7000
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 640000, time elapsed: 4509.77 seconds
# 	 	 Training Loss: 0.9608, Validation Loss: 1.0015
# 	 	 Training Acc: 0.6964, Validation Acc: 0.6857
# 	 	 Last Char Training Acc: 0.7188, Last Char Validation Acc: 0.7437
# --------------------------------------------------
# [save_to_drive] Successfully saved training_results.log to /content/drive/MyDrive/final_model_results
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 650000, time elapsed: 4580.93 seconds
# 	 	 Training Loss: 0.9350, Validation Loss: 1.0127
# 	 	 Training Acc: 0.7023, Validation Acc: 0.6845
# 	 	 Last Char Training Acc: 0.6250, Last Char Validation Acc: 0.6687
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 660000, time elapsed: 4652.06 seconds
# 	 	 Training Loss: 0.9524, Validation Loss: 0.9895
# 	 	 Training Acc: 0.7017, Validation Acc: 0.6902
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.7000
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 670000, time elapsed: 4723.08 seconds
# 	 	 Training Loss: 0.9064, Validation Loss: 0.9868
# 	 	 Training Acc: 0.7117, Validation Acc: 0.6930
# 	 	 Last Char Training Acc: 0.6250, Last Char Validation Acc: 0.7563
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 680000, time elapsed: 4793.80 seconds
# 	 	 Training Loss: 0.9376, Validation Loss: 1.0042
# 	 	 Training Acc: 0.7085, Validation Acc: 0.6856
# 	 	 Last Char Training Acc: 0.7188, Last Char Validation Acc: 0.7000
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 690000, time elapsed: 4863.98 seconds
# 	 	 Training Loss: 0.9474, Validation Loss: 1.0170
# 	 	 Training Acc: 0.7083, Validation Acc: 0.6832
# 	 	 Last Char Training Acc: 0.7812, Last Char Validation Acc: 0.7375
# --------------------------------------------------
# [save_to_drive] Successfully saved training_results.log to /content/drive/MyDrive/final_model_results
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# [save_checkpoint] Saved checkpoint at step 700000 to ./checkpoint.pkl
# [save_to_drive] Successfully saved checkpoint.pkl to /content/drive/MyDrive/final_model_results
# Iteration 700000, time elapsed: 4934.30 seconds
# 	 	 Training Loss: 0.9796, Validation Loss: 0.9722
# 	 	 Training Acc: 0.6902, Validation Acc: 0.6944
# 	 	 Last Char Training Acc: 0.8750, Last Char Validation Acc: 0.6687
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 710000, time elapsed: 5004.53 seconds
# 	 	 Training Loss: 0.9243, Validation Loss: 0.9615
# 	 	 Training Acc: 0.7140, Validation Acc: 0.6981
# 	 	 Last Char Training Acc: 0.6875, Last Char Validation Acc: 0.7375
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 720000, time elapsed: 5079.05 seconds
# 	 	 Training Loss: 0.9004, Validation Loss: 0.9798
# 	 	 Training Acc: 0.7163, Validation Acc: 0.6956
# 	 	 Last Char Training Acc: 0.8438, Last Char Validation Acc: 0.7437
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 730000, time elapsed: 5149.56 seconds
# 	 	 Training Loss: 0.9658, Validation Loss: 0.9655
# 	 	 Training Acc: 0.6949, Validation Acc: 0.6977
# 	 	 Last Char Training Acc: 0.6562, Last Char Validation Acc: 0.7125
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 740000, time elapsed: 5219.76 seconds
# 	 	 Training Loss: 0.9639, Validation Loss: 0.9948
# 	 	 Training Acc: 0.6941, Validation Acc: 0.6892
# 	 	 Last Char Training Acc: 0.6875, Last Char Validation Acc: 0.6500
# --------------------------------------------------
# [save_to_drive] Successfully saved training_results.log to /content/drive/MyDrive/final_model_results
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 750000, time elapsed: 5290.57 seconds
# 	 	 Training Loss: 0.9312, Validation Loss: 0.9776
# 	 	 Training Acc: 0.7052, Validation Acc: 0.6954
# 	 	 Last Char Training Acc: 0.8125, Last Char Validation Acc: 0.7563
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 760000, time elapsed: 5360.87 seconds
# 	 	 Training Loss: 0.9067, Validation Loss: 0.9726
# 	 	 Training Acc: 0.7184, Validation Acc: 0.6965
# 	 	 Last Char Training Acc: 0.8125, Last Char Validation Acc: 0.6812
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 770000, time elapsed: 5430.87 seconds
# 	 	 Training Loss: 0.9383, Validation Loss: 0.9757
# 	 	 Training Acc: 0.7042, Validation Acc: 0.6953
# 	 	 Last Char Training Acc: 0.6250, Last Char Validation Acc: 0.7375
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 780000, time elapsed: 5501.35 seconds
# 	 	 Training Loss: 0.9673, Validation Loss: 0.9684
# 	 	 Training Acc: 0.7001, Validation Acc: 0.6964
# 	 	 Last Char Training Acc: 0.8125, Last Char Validation Acc: 0.7375
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 790000, time elapsed: 5571.21 seconds
# 	 	 Training Loss: 0.9373, Validation Loss: 0.9861
# 	 	 Training Acc: 0.7075, Validation Acc: 0.6917
# 	 	 Last Char Training Acc: 0.7812, Last Char Validation Acc: 0.7250
# --------------------------------------------------
# [save_to_drive] Successfully saved training_results.log to /content/drive/MyDrive/final_model_results
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 800000, time elapsed: 5639.35 seconds
# 	 	 Training Loss: 0.9086, Validation Loss: 0.9975
# 	 	 Training Acc: 0.7139, Validation Acc: 0.6903
# 	 	 Last Char Training Acc: 0.5938, Last Char Validation Acc: 0.6812
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 810000, time elapsed: 5709.14 seconds
# 	 	 Training Loss: 0.8965, Validation Loss: 0.9517
# 	 	 Training Acc: 0.7196, Validation Acc: 0.7016
# 	 	 Last Char Training Acc: 0.7188, Last Char Validation Acc: 0.7375
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 820000, time elapsed: 5778.77 seconds
# 	 	 Training Loss: 0.8775, Validation Loss: 0.9677
# 	 	 Training Acc: 0.7234, Validation Acc: 0.6960
# 	 	 Last Char Training Acc: 0.6562, Last Char Validation Acc: 0.7500
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 830000, time elapsed: 5849.73 seconds
# 	 	 Training Loss: 0.8523, Validation Loss: 0.9458
# 	 	 Training Acc: 0.7307, Validation Acc: 0.7027
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.7000
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 840000, time elapsed: 5919.49 seconds
# 	 	 Training Loss: 0.9241, Validation Loss: 0.9879
# 	 	 Training Acc: 0.7152, Validation Acc: 0.6895
# 	 	 Last Char Training Acc: 0.8125, Last Char Validation Acc: 0.7125
# --------------------------------------------------
# [save_to_drive] Successfully saved training_results.log to /content/drive/MyDrive/final_model_results
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# [save_checkpoint] Saved checkpoint at step 850000 to ./checkpoint.pkl
# [save_to_drive] Successfully saved checkpoint.pkl to /content/drive/MyDrive/final_model_results
# Iteration 850000, time elapsed: 5993.33 seconds
# 	 	 Training Loss: 0.8799, Validation Loss: 0.9428
# 	 	 Training Acc: 0.7230, Validation Acc: 0.7072
# 	 	 Last Char Training Acc: 0.7188, Last Char Validation Acc: 0.7188
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 860000, time elapsed: 6062.40 seconds
# 	 	 Training Loss: 0.8772, Validation Loss: 0.9760
# 	 	 Training Acc: 0.7175, Validation Acc: 0.6963
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.7563
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 870000, time elapsed: 6131.60 seconds
# 	 	 Training Loss: 0.8767, Validation Loss: 0.9501
# 	 	 Training Acc: 0.7209, Validation Acc: 0.7012
# 	 	 Last Char Training Acc: 0.9062, Last Char Validation Acc: 0.6938
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 880000, time elapsed: 6201.79 seconds
# 	 	 Training Loss: 0.9159, Validation Loss: 0.9553
# 	 	 Training Acc: 0.7168, Validation Acc: 0.6997
# 	 	 Last Char Training Acc: 0.5938, Last Char Validation Acc: 0.7125
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 890000, time elapsed: 6272.56 seconds
# 	 	 Training Loss: 0.9043, Validation Loss: 0.9763
# 	 	 Training Acc: 0.7150, Validation Acc: 0.6950
# 	 	 Last Char Training Acc: 0.7188, Last Char Validation Acc: 0.7375
# --------------------------------------------------
# [save_to_drive] Successfully saved training_results.log to /content/drive/MyDrive/final_model_results
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 900000, time elapsed: 6342.61 seconds
# 	 	 Training Loss: 0.9229, Validation Loss: 0.9693
# 	 	 Training Acc: 0.7068, Validation Acc: 0.6987
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.6750
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 910000, time elapsed: 6412.22 seconds
# 	 	 Training Loss: 0.9139, Validation Loss: 0.9356
# 	 	 Training Acc: 0.7126, Validation Acc: 0.7078
# 	 	 Last Char Training Acc: 0.7188, Last Char Validation Acc: 0.7250
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 920000, time elapsed: 6482.35 seconds
# 	 	 Training Loss: 0.9211, Validation Loss: 0.9418
# 	 	 Training Acc: 0.7134, Validation Acc: 0.7084
# 	 	 Last Char Training Acc: 0.6875, Last Char Validation Acc: 0.7375
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 930000, time elapsed: 6553.57 seconds
# 	 	 Training Loss: 0.8617, Validation Loss: 0.9682
# 	 	 Training Acc: 0.7234, Validation Acc: 0.6991
# 	 	 Last Char Training Acc: 0.8438, Last Char Validation Acc: 0.7625
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 940000, time elapsed: 6623.75 seconds
# 	 	 Training Loss: 0.8963, Validation Loss: 0.9447
# 	 	 Training Acc: 0.7170, Validation Acc: 0.7066
# 	 	 Last Char Training Acc: 0.6562, Last Char Validation Acc: 0.7250
# --------------------------------------------------
# [save_to_drive] Successfully saved training_results.log to /content/drive/MyDrive/final_model_results
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 950000, time elapsed: 6695.59 seconds
# 	 	 Training Loss: 0.8738, Validation Loss: 0.9662
# 	 	 Training Acc: 0.7241, Validation Acc: 0.7003
# 	 	 Last Char Training Acc: 0.8125, Last Char Validation Acc: 0.7063
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 960000, time elapsed: 6765.30 seconds
# 	 	 Training Loss: 0.9149, Validation Loss: 0.9487
# 	 	 Training Acc: 0.7119, Validation Acc: 0.7043
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.7750
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 970000, time elapsed: 6836.16 seconds
# 	 	 Training Loss: 0.8879, Validation Loss: 0.9526
# 	 	 Training Acc: 0.7225, Validation Acc: 0.7026
# 	 	 Last Char Training Acc: 0.8125, Last Char Validation Acc: 0.7437
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 980000, time elapsed: 6906.01 seconds
# 	 	 Training Loss: 0.9243, Validation Loss: 0.9337
# 	 	 Training Acc: 0.7101, Validation Acc: 0.7066
# 	 	 Last Char Training Acc: 0.7500, Last Char Validation Acc: 0.7063
# --------------------------------------------------
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# Iteration 990000, time elapsed: 6976.65 seconds
# 	 	 Training Loss: 0.8479, Validation Loss: 0.9793
# 	 	 Training Acc: 0.7346, Validation Acc: 0.6961
# 	 	 Last Char Training Acc: 0.6875, Last Char Validation Acc: 0.7063
# --------------------------------------------------
# [save_to_drive] Successfully saved training_results.log to /content/drive/MyDrive/final_model_results
# [save_to_drive] Successfully saved validation_results.log to /content/drive/MyDrive/final_model_results
# [save_checkpoint] Saved checkpoint at step 999999 to ./checkpoint.pkl
# [save_to_drive] Successfully saved checkpoint.pkl to /content/drive/MyDrive/final_model_results
# Iteration 999999, time elapsed: 7046.68 seconds
# 	 	 Training Loss: 0.8730, Validation Loss: 0.9391
# 	 	 Training Acc: 0.7242, Validation Acc: 0.7096
# 	 	 Last Char Training Acc: 0.7188, Last Char Validation Acc: 0.7312
# --------------------------------------------------
# Training completed in 7046.87 seconds.

# %% [markdown]
# ## Testing the model on test data
#
# Finally, we test the trained model on the test dataset over a set number of batches (`evaluation_batches`) to evaluate its performance. The test loss, accuracy and accuracy of the last character prediction are computed and reported.

# %%
# No. of batches to use for evaluation
evaluation_batches = 100

total_test_loss, total_test_acc, total_last_char_test_acc = tr_utils.evaluate_on_test_set(
    rng = rng,
    model = model_obj,
    params = params,
    constants = constants,
    test_data = test_data,
    batch_size = batch_size,
    seq_len = seq_len,
    loss_type = loss_type,
    aux_loss = use_auxiliary_loss,
    aux_weight = aux_weight,
    label_smoothing = label_smoothing,
    n_batches = evaluation_batches
)

for i in range(evaluation_batches):

    # Update test log
    su_utils.update_test_log(
        log_path = "./test_results.log",
        test_loss = total_test_loss[i],
        test_acc = total_test_acc[i],
        last_char_test_acc = total_last_char_test_acc[i]
    )

# Save test log to google drive
su_utils.save_to_drive(
    drive_backup_dir=DRIVE_BACKUP_DIR,
    file_name="test_results.log"
)
# Out:
# [evaluate_on_test_set] Metrics are averaged over 100 batches.
# Mean Test Loss: 0.9621, Mean Test Accuracy: 0.7007, Mean Last Character Test Accuracy: 0.7109
# Min Test Acc: 0.6779, Max Test Accuracy: 0.7229, Max Last Character Test Accuracy: 0.9375
# Max Test Acc: 0.7229, Min Test Accuracy: 0.6779, Min Last Character Test Accuracy: 0.5000
# S.D of Test Acc: 0.0087, S.D of Test Accuracy: 0.0087, S.D of Last Character Test Accuracy: 0.0866
#
# [save_to_drive] Successfully saved test_results.log to /content/drive/MyDrive/final_model_results

# %% [markdown]
# ## Plot the loss and accuracy curves
#
# After training, we plot the training and validation loss curves to visualize the model's learning progress over time. This plot is saved to the specified output directory, and will be useful to observe trends such as overfitting or underfitting.
#
# We also plot the training and validation accuracy curves to visualize the model's performance over time. This plot is saved to the specified output directory, and will help in assessing how well the model is learning to predict the next character in the sequence. We add in the mean test accuracy as well for comparison.

# %%
name_of_plot = "loss_curve"

# Plot training and validation loss curves
plt.plot(train_step_history, train_loss_history, "-",label='Training Loss', color='blue')
plt.plot(val_step_history, val_loss_history, "-", label='Validation Loss', lw = 2, color='red')
plt.xlabel("Iteration")
plt.ylabel("Loss")
plt.legend(loc = "upper right")
plt.title("Training and Validation Loss over Iterations")
plt.legend()
plt.savefig(f"./{name_of_plot}.png")
plt.show()

# Save plots to Drive
su_utils.save_to_drive(
    drive_backup_dir=DRIVE_BACKUP_DIR,
    file_name=f"{name_of_plot}.png"
)
# Out:
# [save_to_drive] Successfully saved loss_curve.png to /content/drive/MyDrive/final_model_results

# %%
# Save plots to Drive
name_of_plot = "accuracy_curve"

# Plot training and validation loss curves
plt.plot(train_step_history, train_acc_history, "-",label='Training Accuracy', color='blue')
plt.plot(val_step_history, val_acc_history, "-", label='Validation Accuracy', lw = 2, color='red')
plt.scatter([iter_max], np.mean(total_test_acc), label='Test Accuracy', color='green', s = 50)
plt.xlabel("Iteration")
plt.ylabel("Accuracy")
plt.legend(loc = "upper right")
plt.title("Training and Validation Accuracy over Iterations")
plt.legend()
plt.savefig(f"./{name_of_plot}.png")
plt.show()

# Save plots to Drive
su_utils.save_to_drive(
    drive_backup_dir=DRIVE_BACKUP_DIR,
    file_name=f"{name_of_plot}.png"
)
# Out:
# [save_to_drive] Successfully saved accuracy_curve.png to /content/drive/MyDrive/final_model_results

# %%
name_of_plot = "last_char_accuracy_curve"

# Plot training and validation loss curves
plt.plot(train_step_history, last_char_train_acc_history, "-",label='Training Accuracy for last char', color='blue')
plt.plot(val_step_history, last_char_val_acc_history, "-", label='Validation Accuracy for last char', lw = 2, color='red')
plt.scatter([iter_max], np.mean(total_last_char_test_acc), label='Test Accuracy for last char', color='green', s = 50)
plt.xlabel("Iteration")
plt.ylabel("Accuracy")
plt.legend(loc = "upper right")
plt.title("Training and Validation Accuracy for Last Character over Iterations")
plt.legend()
plt.savefig(f"./{name_of_plot}.png")
plt.show()

# Save plots to Drive
su_utils.save_to_drive(
    drive_backup_dir=DRIVE_BACKUP_DIR,
    file_name=f"{name_of_plot}.png"
)
# Out:
# [save_to_drive] Successfully saved last_char_accuracy_curve.png to /content/drive/MyDrive/final_model_results

# %% [markdown]
# # Testing the model on a given prompt
#
# We finally test the trained model by generating text based on a given prompt. The model successfully generates a sequence of characters that continue from the prompt, and we save the generated text to a file for review.

# %%
# Test the model on a given prompt
prompt = "the meaning of life is"
encoded_prompt = tr_utils.encode(prompt, chars_to_int)
context = encoded_prompt[None, :]

generate_len = 1000
rng = jax.random.PRNGKey(seed)

output_indices = tr_utils.generate_tokens(
    model=model_obj,
    params=params,
    constants=constants,
    rng=rng,
    context=context,
    length=generate_len,
    block_size=seq_len,
    temperature=0.8,
    sample=True,
    pad_id=None,
    deterministic=True
)

output_indices = np.array(output_indices)  # Convert from JAX array to NumPy array
generated_text = tr_utils.decode(output_indices, int_to_chars)

print("Generated ID Shape:", output_indices.shape)
print("Generated Text:")
print(prompt + generated_text)

generated_text_file = "./generated_text.txt"

with open(generated_text_file, "w") as f:
    f.write(prompt + generated_text)
    print(f"[Sample text generation] Generated text saved to {generated_text_file}.")

# Save generated text to Drive
su_utils.save_to_drive(
    drive_backup_dir=DRIVE_BACKUP_DIR,
    file_name="generated_text.txt"
)
# Out:
# Generated ID Shape: (1, 1000)
# Generated Text:
# the meaning of life is to reproduce the party or on the principles of counter syndrome notable comous encodings in the one nine nine five gsa relationship with the united states in hope that dubbed halfpurt s efforts to prevent individual images and a cultural connection contemporary with others the state of gsa is the country s largest city and the capital the united states federal information service court is the responsible source of the capital court for the central government the town boarded a majority of the one one four member states the uk printing commission since one six march one nine eight four and has produced the check degree conducted by the constitution the terms of the constitution of one six may government member states the uk government s three three members and one eight members divided the one zero member states the united states has no nonviblockage or occasionally divided between the two thirds of the world s population the faroe islands whose total territory is tied to the european
# [Sample text generation] Generated text saved to ./generated_text.txt.
# [save_to_drive] Successfully saved generated_text.txt to /content/drive/MyDrive/final_model_results
